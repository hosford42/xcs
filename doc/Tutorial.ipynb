# %% [markdown]
# # XCS Tutorial
#
# This is the official tutorial for the [xcs package](https://pypi.python.org/pypi/xcs) for Python 3. You can find the latest release and get updates on the project's status at the [project home page](https://github.com/hosford42/xcs) on GitHub.com.
#
# ## Installation
#
# If you have pip, installation is straight forward:

# %% [raw]
# pip install xcs

# %% [markdown]
# If this goes as planned, you should see a message like this:

# %% [raw]
# Successfully installed xcs-1.0.0

# %% [markdown]
# It is recommended that you also install numpy, though the xcs package will still work, albeit more slowly, without it.

# %% [raw]
# pip install numpy

# %% [markdown]
# If you are unable to use pip, you can still install xcs manually. The latest release can be found [here](https://github.com/hosford42/xcs/releases) or [here](https://pypi.python.org/pypi/xcs). Download the zip file, unpack it, and cd into the directory. Then run:

# %% [raw]
# python setup.py install

# %% [markdown]
# You should see a message indicating that the package was successfully installed. For instructions on how to manually install numpy, visit the [numpy installation instructions page](http://docs.scipy.org/doc/numpy/user/install.html) at SciPy.org.

# %% [markdown]
# ## Testing the Newly Installed Package
#
# Let's start things off with a quick test, to verify that everything has been installed properly. First, we set up logging so we can see the test's progress.

# %%
import logging
logging.root.setLevel(logging.INFO)

# %% [markdown]
# Then we import the xcs module and run the built-in test() function. By default, the test() function runs the canonical XCS algorithm on the 11-bit (3-bit address) MUX problem for 10,000 steps.

# %%
import xcs
xcs.test()
# Out:
# INFO:xcs.problems:Possible actions:
# INFO:xcs.problems:    False
# INFO:xcs.problems:    True
# INFO:xcs.problems:Steps completed: 0
# INFO:xcs.problems:Average reward per step: 0.00000
# INFO:xcs.problems:Steps completed: 100
# INFO:xcs.problems:Average reward per step: 0.46000
# INFO:xcs.problems:Steps completed: 200
# INFO:xcs.problems:Average reward per step: 0.52000
# INFO:xcs.problems:Steps completed: 300
# INFO:xcs.problems:Average reward per step: 0.52333
# INFO:xcs.problems:Steps completed: 400
# INFO:xcs.problems:Average reward per step: 0.52500
# INFO:xcs.problems:Steps completed: 500
# INFO:xcs.problems:Average reward per step: 0.53600
# INFO:xcs.problems:Steps completed: 600
# INFO:xcs.problems:Average reward per step: 0.54667
# INFO:xcs.problems:Steps completed: 700
# INFO:xcs.problems:Average reward per step: 0.54571
# INFO:xcs.problems:Steps completed: 800
# INFO:xcs.problems:Average reward per step: 0.54875
# INFO:xcs.problems:Steps completed: 900
# INFO:xcs.problems:Average reward per step: 0.55444
# INFO:xcs.problems:Steps completed: 1000
# INFO:xcs.problems:Average reward per step: 0.55400
# INFO:xcs.problems:Steps completed: 1100
# INFO:xcs.problems:Average reward per step: 0.55909
# INFO:xcs.problems:Steps completed: 1200
# INFO:xcs.problems:Average reward per step: 0.55750
# INFO:xcs.problems:Steps completed: 1300
# INFO:xcs.problems:Average reward per step: 0.55692
# INFO:xcs.problems:Steps completed: 1400
# INFO:xcs.problems:Average reward per step: 0.56071
# INFO:xcs.problems:Steps completed: 1500
# INFO:xcs.problems:Average reward per step: 0.55867
# INFO:xcs.problems:Steps completed: 1600
# INFO:xcs.problems:Average reward per step: 0.56625
# INFO:xcs.problems:Steps completed: 1700
# INFO:xcs.problems:Average reward per step: 0.57471
# INFO:xcs.problems:Steps completed: 1800
# INFO:xcs.problems:Average reward per step: 0.58111
# INFO:xcs.problems:Steps completed: 1900
# INFO:xcs.problems:Average reward per step: 0.58105
# INFO:xcs.problems:Steps completed: 2000
# INFO:xcs.problems:Average reward per step: 0.58300
# INFO:xcs.problems:Steps completed: 2100
# INFO:xcs.problems:Average reward per step: 0.58333
# INFO:xcs.problems:Steps completed: 2200
# INFO:xcs.problems:Average reward per step: 0.58136
# INFO:xcs.problems:Steps completed: 2300
# INFO:xcs.problems:Average reward per step: 0.58174
# INFO:xcs.problems:Steps completed: 2400
# INFO:xcs.problems:Average reward per step: 0.58250
# INFO:xcs.problems:Steps completed: 2500
# INFO:xcs.problems:Average reward per step: 0.58360
# INFO:xcs.problems:Steps completed: 2600
# INFO:xcs.problems:Average reward per step: 0.58269
# INFO:xcs.problems:Steps completed: 2700
# INFO:xcs.problems:Average reward per step: 0.58407
# INFO:xcs.problems:Steps completed: 2800
# INFO:xcs.problems:Average reward per step: 0.58393
# INFO:xcs.problems:Steps completed: 2900
# INFO:xcs.problems:Average reward per step: 0.58759
# INFO:xcs.problems:Steps completed: 3000
# INFO:xcs.problems:Average reward per step: 0.58967
# INFO:xcs.problems:Steps completed: 3100
# INFO:xcs.problems:Average reward per step: 0.59032
# INFO:xcs.problems:Steps completed: 3200
# INFO:xcs.problems:Average reward per step: 0.58906
# INFO:xcs.problems:Steps completed: 3300
# INFO:xcs.problems:Average reward per step: 0.59212
# INFO:xcs.problems:Steps completed: 3400
# INFO:xcs.problems:Average reward per step: 0.59441
# INFO:xcs.problems:Steps completed: 3500
# INFO:xcs.problems:Average reward per step: 0.59600
# INFO:xcs.problems:Steps completed: 3600
# INFO:xcs.problems:Average reward per step: 0.59667
# INFO:xcs.problems:Steps completed: 3700
# INFO:xcs.problems:Average reward per step: 0.59730
# INFO:xcs.problems:Steps completed: 3800
# INFO:xcs.problems:Average reward per step: 0.59868
# INFO:xcs.problems:Steps completed: 3900
# INFO:xcs.problems:Average reward per step: 0.60231
# INFO:xcs.problems:Steps completed: 4000
# INFO:xcs.problems:Average reward per step: 0.60475
# INFO:xcs.problems:Steps completed: 4100
# INFO:xcs.problems:Average reward per step: 0.60683
# INFO:xcs.problems:Steps completed: 4200
# INFO:xcs.problems:Average reward per step: 0.60881
# INFO:xcs.problems:Steps completed: 4300
# INFO:xcs.problems:Average reward per step: 0.60744
# INFO:xcs.problems:Steps completed: 4400
# INFO:xcs.problems:Average reward per step: 0.60841
# INFO:xcs.problems:Steps completed: 4500
# INFO:xcs.problems:Average reward per step: 0.61000
# INFO:xcs.problems:Steps completed: 4600
# INFO:xcs.problems:Average reward per step: 0.61174
# INFO:xcs.problems:Steps completed: 4700
# INFO:xcs.problems:Average reward per step: 0.61468
# INFO:xcs.problems:Steps completed: 4800
# INFO:xcs.problems:Average reward per step: 0.61813
# INFO:xcs.problems:Steps completed: 4900
# INFO:xcs.problems:Average reward per step: 0.62061
# INFO:xcs.problems:Steps completed: 5000
# INFO:xcs.problems:Average reward per step: 0.62060
# INFO:xcs.problems:Steps completed: 5100
# INFO:xcs.problems:Average reward per step: 0.62235
# INFO:xcs.problems:Steps completed: 5200
# INFO:xcs.problems:Average reward per step: 0.62404
# INFO:xcs.problems:Steps completed: 5300
# INFO:xcs.problems:Average reward per step: 0.62509
# INFO:xcs.problems:Steps completed: 5400
# INFO:xcs.problems:Average reward per step: 0.62648
# INFO:xcs.problems:Steps completed: 5500
# INFO:xcs.problems:Average reward per step: 0.62927
# INFO:xcs.problems:Steps completed: 5600
# INFO:xcs.problems:Average reward per step: 0.63018
# INFO:xcs.problems:Steps completed: 5700
# INFO:xcs.problems:Average reward per step: 0.63211
# INFO:xcs.problems:Steps completed: 5800
# INFO:xcs.problems:Average reward per step: 0.63379
# INFO:xcs.problems:Steps completed: 5900
# INFO:xcs.problems:Average reward per step: 0.63475
# INFO:xcs.problems:Steps completed: 6000
# INFO:xcs.problems:Average reward per step: 0.63483
# INFO:xcs.problems:Steps completed: 6100
# INFO:xcs.problems:Average reward per step: 0.63656
# INFO:xcs.problems:Steps completed: 6200
# INFO:xcs.problems:Average reward per step: 0.63839
# INFO:xcs.problems:Steps completed: 6300
# INFO:xcs.problems:Average reward per step: 0.63937
# INFO:xcs.problems:Steps completed: 6400
# INFO:xcs.problems:Average reward per step: 0.64062
# INFO:xcs.problems:Steps completed: 6500
# INFO:xcs.problems:Average reward per step: 0.64231
# INFO:xcs.problems:Steps completed: 6600
# INFO:xcs.problems:Average reward per step: 0.64394
# INFO:xcs.problems:Steps completed: 6700
# INFO:xcs.problems:Average reward per step: 0.64507
# INFO:xcs.problems:Steps completed: 6800
# INFO:xcs.problems:Average reward per step: 0.64632
# INFO:xcs.problems:Steps completed: 6900
# INFO:xcs.problems:Average reward per step: 0.64696
# INFO:xcs.problems:Steps completed: 7000
# INFO:xcs.problems:Average reward per step: 0.64829
# INFO:xcs.problems:Steps completed: 7100
# INFO:xcs.problems:Average reward per step: 0.65070
# INFO:xcs.problems:Steps completed: 7200
# INFO:xcs.problems:Average reward per step: 0.65181
# INFO:xcs.problems:Steps completed: 7300
# INFO:xcs.problems:Average reward per step: 0.65301
# INFO:xcs.problems:Steps completed: 7400
# INFO:xcs.problems:Average reward per step: 0.65486
# INFO:xcs.problems:Steps completed: 7500
# INFO:xcs.problems:Average reward per step: 0.65640
# INFO:xcs.problems:Steps completed: 7600
# INFO:xcs.problems:Average reward per step: 0.65776
# INFO:xcs.problems:Steps completed: 7700
# INFO:xcs.problems:Average reward per step: 0.65896
# INFO:xcs.problems:Steps completed: 7800
# INFO:xcs.problems:Average reward per step: 0.66038
# INFO:xcs.problems:Steps completed: 7900
# INFO:xcs.problems:Average reward per step: 0.66114
# INFO:xcs.problems:Steps completed: 8000
# INFO:xcs.problems:Average reward per step: 0.66163
# INFO:xcs.problems:Steps completed: 8100
# INFO:xcs.problems:Average reward per step: 0.66210
# INFO:xcs.problems:Steps completed: 8200
# INFO:xcs.problems:Average reward per step: 0.66329
# INFO:xcs.problems:Steps completed: 8300
# INFO:xcs.problems:Average reward per step: 0.66386
# INFO:xcs.problems:Steps completed: 8400
# INFO:xcs.problems:Average reward per step: 0.66619
# INFO:xcs.problems:Steps completed: 8500
# INFO:xcs.problems:Average reward per step: 0.66753
# INFO:xcs.problems:Steps completed: 8600
# INFO:xcs.problems:Average reward per step: 0.66919
# INFO:xcs.problems:Steps completed: 8700
# INFO:xcs.problems:Average reward per step: 0.66966
# INFO:xcs.problems:Steps completed: 8800
# INFO:xcs.problems:Average reward per step: 0.67045
# INFO:xcs.problems:Steps completed: 8900
# INFO:xcs.problems:Average reward per step: 0.67157
# INFO:xcs.problems:Steps completed: 9000
# INFO:xcs.problems:Average reward per step: 0.67233
# INFO:xcs.problems:Steps completed: 9100
# INFO:xcs.problems:Average reward per step: 0.67341
# INFO:xcs.problems:Steps completed: 9200
# INFO:xcs.problems:Average reward per step: 0.67391
# INFO:xcs.problems:Steps completed: 9300
# INFO:xcs.problems:Average reward per step: 0.67559
# INFO:xcs.problems:Steps completed: 9400
# INFO:xcs.problems:Average reward per step: 0.67638
# INFO:xcs.problems:Steps completed: 9500
# INFO:xcs.problems:Average reward per step: 0.67716
# INFO:xcs.problems:Steps completed: 9600
# INFO:xcs.problems:Average reward per step: 0.67885
# INFO:xcs.problems:Steps completed: 9700
# INFO:xcs.problems:Average reward per step: 0.67938
# INFO:xcs.problems:Steps completed: 9800
# INFO:xcs.problems:Average reward per step: 0.67990
# INFO:xcs.problems:Steps completed: 9900
# INFO:xcs.problems:Average reward per step: 0.68111
# INFO:xcs.problems:Steps completed: 10000
# INFO:xcs.problems:Average reward per step: 0.68210
# INFO:xcs.problems:Run completed.
# INFO:xcs.problems:Total steps: 10000
# INFO:xcs.problems:Total reward received: 6821.00000
# INFO:xcs.problems:Average reward per step: 0.68210
# INFO:xcs:Population:
#
# ##1#1#0###0 => False
#     Time Stamp: 9975
#     Average Reward: 0.915173884214
#     Error: 0.177260847296
#     Fitness: 0.000208859305683
#     Experience: 33
#     Action Set Size: 73.05548355797696
#     Numerosity: 1
# 01###0####1 => False
#     Time Stamp: 9991
#     Average Reward: 0.990948681868
#     Error: 0.0389126381496
#     Fitness: 0.000291976378205
#     Experience: 59
#     Action Set Size: 50.07172775739006
#     Numerosity: 1
# 01011###0## => False
#     Time Stamp: 9894
#     Average Reward: 0.930219006784
#     Error: 0.142005277899
#     Fitness: 0.000517402672007
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #10110##0#1 => False
#     Time Stamp: 9894
#     Average Reward: 0.930219006784
#     Error: 0.142005277899
#     Fitness: 0.000517402672007
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# ##1#1###0## => False
#     Time Stamp: 9990
#     Average Reward: 0.818250504724
#     Error: 0.25508093818
#     Fitness: 0.000818429695271
#     Experience: 35
#     Action Set Size: 56.57467100868276
#     Numerosity: 1
# ##1#1#####0 => False
#     Time Stamp: 9990
#     Average Reward: 0.81721906025
#     Error: 0.26235857486
#     Fitness: 0.00101543731983
#     Experience: 105
#     Action Set Size: 61.83627942845774
#     Numerosity: 1
# ######0#### => True
#     Time Stamp: 9995
#     Average Reward: 0.812712757994
#     Error: 0.306448571345
#     Fitness: 0.0010326597151
#     Experience: 331
#     Action Set Size: 48.10245282893745
#     Numerosity: 1
# 111######## => True
#     Time Stamp: 9952
#     Average Reward: 0.895764708187
#     Error: 0.18839842557
#     Fitness: 0.00116095963694
#     Experience: 23
#     Action Set Size: 75.984566657701
#     Numerosity: 1
# #01######## => False
#     Time Stamp: 9986
#     Average Reward: 0.81866810464
#     Error: 0.293501584571
#     Fitness: 0.00118449174066
#     Experience: 177
#     Action Set Size: 50.398550016191415
#     Numerosity: 1
# ####00####0 => False
#     Time Stamp: 9924
#     Average Reward: 0.896720014274
#     Error: 0.226490298131
#     Fitness: 0.00124042781616
#     Experience: 74
#     Action Set Size: 45.831941325112716
#     Numerosity: 1
# 1#1###0##0# => False
#     Time Stamp: 9986
#     Average Reward: 0.76836386589
#     Error: 0.306892246732
#     Fitness: 0.00124086268243
#     Experience: 34
#     Action Set Size: 70.06104086260807
#     Numerosity: 1
# #1####0#### => False
#     Time Stamp: 9951
#     Average Reward: 0.936580226311
#     Error: 0.14269297959
#     Fitness: 0.00126243070522
#     Experience: 53
#     Action Set Size: 60.8798624804318
#     Numerosity: 1
# 1#1#0###### => True
#     Time Stamp: 9999
#     Average Reward: 0.849949770882
#     Error: 0.279906368559
#     Fitness: 0.00134169852609
#     Experience: 38
#     Action Set Size: 57.285655794454144
#     Numerosity: 1
# 0#0#0#11### => True
#     Time Stamp: 9844
#     Average Reward: 0.772304369053
#     Error: 0.335877314279
#     Fitness: 0.00135199895592
#     Experience: 35
#     Action Set Size: 54.35785768496199
#     Numerosity: 1
# #11#####0#0 => False
#     Time Stamp: 9990
#     Average Reward: 0.78976155009
#     Error: 0.274366258824
#     Fitness: 0.00147981087083
#     Experience: 37
#     Action Set Size: 66.76364169053788
#     Numerosity: 1
# 111#####1## => True
#     Time Stamp: 9918
#     Average Reward: 0.893269580284
#     Error: 0.201238886052
#     Fitness: 0.00154227056786
#     Experience: 38
#     Action Set Size: 92.03316002529712
#     Numerosity: 1
# 1#0#0#####1 => True
#     Time Stamp: 9981
#     Average Reward: 0.80536703142
#     Error: 0.288462234224
#     Fitness: 0.00157047975219
#     Experience: 35
#     Action Set Size: 62.54596777983915
#     Numerosity: 1
# 11#0#0###01 => True
#     Time Stamp: 9952
#     Average Reward: 0.91103789847
#     Error: 0.209790358665
#     Fitness: 0.00162466662154
#     Experience: 21
#     Action Set Size: 78.8748416941886
#     Numerosity: 1
# #11#######0 => False
#     Time Stamp: 9990
#     Average Reward: 0.823072209008
#     Error: 0.211554321841
#     Fitness: 0.00164149968803
#     Experience: 269
#     Action Set Size: 60.343383184697025
#     Numerosity: 1
# 1#####0#### => False
#     Time Stamp: 9986
#     Average Reward: 0.768771115726
#     Error: 0.327848079308
#     Fitness: 0.00164339008705
#     Experience: 82
#     Action Set Size: 61.16426766252724
#     Numerosity: 1
# 10#11#0#### => False
#     Time Stamp: 9975
#     Average Reward: 0.882784840067
#     Error: 0.243271885982
#     Fitness: 0.00165978670753
#     Experience: 40
#     Action Set Size: 50.88200381755357
#     Numerosity: 1
# 1##0####1#1 => True
#     Time Stamp: 9944
#     Average Reward: 0.990824332166
#     Error: 0.035470306029
#     Fitness: 0.00180153959401
#     Experience: 50
#     Action Set Size: 74.23022677232368
#     Numerosity: 1
# #00####0### => False
#     Time Stamp: 9966
#     Average Reward: 0.987513282178
#     Error: 0.0461217202822
#     Fitness: 0.00183238959585
#     Experience: 56
#     Action Set Size: 58.53519216881137
#     Numerosity: 1
# ###0####0## => False
#     Time Stamp: 9990
#     Average Reward: 0.8145559995
#     Error: 0.224899603217
#     Fitness: 0.00188223141402
#     Experience: 36
#     Action Set Size: 49.31479798996352
#     Numerosity: 1
# 1##0##1#1## => True
#     Time Stamp: 9944
#     Average Reward: 0.945634033666
#     Error: 0.134619945621
#     Fitness: 0.00189234217221
#     Experience: 38
#     Action Set Size: 64.4081554267632
#     Numerosity: 1
# #########1# => True
#     Time Stamp: 9999
#     Average Reward: 0.897153408214
#     Error: 0.228078568816
#     Fitness: 0.00193116782392
#     Experience: 159
#     Action Set Size: 60.80043263856734
#     Numerosity: 1
# 1110####### => True
#     Time Stamp: 9952
#     Average Reward: 0.957210496587
#     Error: 0.102586217054
#     Fitness: 0.00207528671023
#     Experience: 45
#     Action Set Size: 81.19952956633024
#     Numerosity: 1
# 0##1#0##### => False
#     Time Stamp: 9991
#     Average Reward: 0.810775856697
#     Error: 0.26965113898
#     Fitness: 0.00214618874828
#     Experience: 58
#     Action Set Size: 42.27657430785881
#     Numerosity: 1
# ###10###1#1 => True
#     Time Stamp: 9949
#     Average Reward: 0.909169824987
#     Error: 0.202854057529
#     Fitness: 0.00214657029818
#     Experience: 14
#     Action Set Size: 54.69090207250651
#     Numerosity: 1
# ###10###### => True
#     Time Stamp: 9999
#     Average Reward: 0.839675865852
#     Error: 0.219038111632
#     Fitness: 0.00215992785183
#     Experience: 248
#     Action Set Size: 49.399408585461046
#     Numerosity: 1
# ##0111##### => True
#     Time Stamp: 9980
#     Average Reward: 0.99316008275
#     Error: 0.0253076938258
#     Fitness: 0.00221216334018
#     Experience: 26
#     Action Set Size: 63.125272661664596
#     Numerosity: 1
# ####0#01#1# => False
#     Time Stamp: 9984
#     Average Reward: 0.762276756081
#     Error: 0.28531871188
#     Fitness: 0.00232230192864
#     Experience: 32
#     Action Set Size: 42.0849301981974
#     Numerosity: 1
# #01#0##1#0# => False
#     Time Stamp: 9879
#     Average Reward: 0.984479106787
#     Error: 0.0590847814445
#     Fitness: 0.00236145987402
#     Experience: 77
#     Action Set Size: 42.978537878069794
#     Numerosity: 1
# 1###1##1##1 => True
#     Time Stamp: 9995
#     Average Reward: 0.955268552111
#     Error: 0.127642355307
#     Fitness: 0.00237499977668
#     Experience: 59
#     Action Set Size: 75.19933290846836
#     Numerosity: 1
# 11001##1### => True
#     Time Stamp: 9995
#     Average Reward: 0.951586844094
#     Error: 0.129299934672
#     Fitness: 0.00239911414142
#     Experience: 24
#     Action Set Size: 67.67179980113139
#     Numerosity: 1
# #0#####0### => False
#     Time Stamp: 9986
#     Average Reward: 0.833113521218
#     Error: 0.230660541626
#     Fitness: 0.00243133875911
#     Experience: 191
#     Action Set Size: 52.913938635865755
#     Numerosity: 1
# 0##0##1##0# => False
#     Time Stamp: 9892
#     Average Reward: 0.849164564555
#     Error: 0.285807209238
#     Fitness: 0.00243345382168
#     Experience: 30
#     Action Set Size: 49.89785198126422
#     Numerosity: 1
# ##1#0##1#1# => False
#     Time Stamp: 9959
#     Average Reward: 0.941613255305
#     Error: 0.152643774675
#     Fitness: 0.00243638118503
#     Experience: 42
#     Action Set Size: 45.248146518647445
#     Numerosity: 1
# 0#0###11### => True
#     Time Stamp: 9980
#     Average Reward: 0.890073052836
#     Error: 0.22679095014
#     Fitness: 0.00244969612233
#     Experience: 26
#     Action Set Size: 64.50923324768168
#     Numerosity: 1
# ###1####### => True
#     Time Stamp: 9999
#     Average Reward: 0.816560378068
#     Error: 0.258620623536
#     Fitness: 0.00245791243328
#     Experience: 110
#     Action Set Size: 54.80528565749424
#     Numerosity: 1
# ########### => False
#     Time Stamp: 9991
#     Average Reward: 0.714547488625
#     Error: 0.359989603954
#     Fitness: 0.0025796972642
#     Experience: 962
#     Action Set Size: 47.67971619812032
#     Numerosity: 1
# 1#1#######0 => False
#     Time Stamp: 9975
#     Average Reward: 0.987652878783
#     Error: 0.0483502020273
#     Fitness: 0.00262093545252
#     Experience: 42
#     Action Set Size: 65.31632800693444
#     Numerosity: 1
# ###01#10##0 => True
#     Time Stamp: 9744
#     Average Reward: 0.901153649585
#     Error: 0.222034293888
#     Fitness: 0.00268385064673
#     Experience: 33
#     Action Set Size: 48.29826563607957
#     Numerosity: 1
# ####0#####1 => True
#     Time Stamp: 9981
#     Average Reward: 0.783040109037
#     Error: 0.317112541168
#     Fitness: 0.00271758595208
#     Experience: 47
#     Action Set Size: 56.256867426754866
#     Numerosity: 1
# ##1#1##0### => False
#     Time Stamp: 9990
#     Average Reward: 0.698913050553
#     Error: 0.372802811007
#     Fitness: 0.00277060315893
#     Experience: 62
#     Action Set Size: 58.87947386025108
#     Numerosity: 1
# 001000###0# => False
#     Time Stamp: 9798
#     Average Reward: 0.976825438336
#     Error: 0.0747379424219
#     Fitness: 0.00282720678841
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# ####0#0##10 => False
#     Time Stamp: 9911
#     Average Reward: 0.85736844349
#     Error: 0.221691493446
#     Fitness: 0.00294331998846
#     Experience: 20
#     Action Set Size: 51.48603445948303
#     Numerosity: 1
# 00#1#####1# => True
#     Time Stamp: 9940
#     Average Reward: 0.95515922174
#     Error: 0.099593514476
#     Fitness: 0.00296976820196
#     Experience: 29
#     Action Set Size: 73.7459660290378
#     Numerosity: 1
# 1####1#101# => True
#     Time Stamp: 9995
#     Average Reward: 0.743867985346
#     Error: 0.381721995926
#     Fitness: 0.00300026111159
#     Experience: 35
#     Action Set Size: 61.835796775197885
#     Numerosity: 1
# ####01#0### => False
#     Time Stamp: 9986
#     Average Reward: 0.679424100006
#     Error: 0.370733597703
#     Fitness: 0.00308344762171
#     Experience: 195
#     Action Set Size: 47.83367706064852
#     Numerosity: 1
# 01#0#0##### => False
#     Time Stamp: 9990
#     Average Reward: 0.772523245254
#     Error: 0.28473696254
#     Fitness: 0.00336407275568
#     Experience: 53
#     Action Set Size: 56.782290652374016
#     Numerosity: 1
# 0#0##01#### => True
#     Time Stamp: 9767
#     Average Reward: 0.733463681934
#     Error: 0.382269538332
#     Fitness: 0.00340131084531
#     Experience: 29
#     Action Set Size: 47.997146272677874
#     Numerosity: 1
# 0##0##0#### => False
#     Time Stamp: 9966
#     Average Reward: 0.950434590437
#     Error: 0.134335339372
#     Fitness: 0.00346309765641
#     Experience: 55
#     Action Set Size: 53.56215874002258
#     Numerosity: 1
# ##########1 => False
#     Time Stamp: 9991
#     Average Reward: 0.687300287025
#     Error: 0.392646496069
#     Fitness: 0.00351765934541
#     Experience: 61
#     Action Set Size: 41.724052573553614
#     Numerosity: 1
# ##1####1#1# => False
#     Time Stamp: 9975
#     Average Reward: 0.885927166645
#     Error: 0.233995466973
#     Fitness: 0.00354545571764
#     Experience: 41
#     Action Set Size: 46.26001968553245
#     Numerosity: 1
# 1#1#######1 => True
#     Time Stamp: 9952
#     Average Reward: 0.921569945689
#     Error: 0.175877819532
#     Fitness: 0.00359094769034
#     Experience: 51
#     Action Set Size: 67.57173959092731
#     Numerosity: 1
# ####1#1#### => True
#     Time Stamp: 9980
#     Average Reward: 0.991173210425
#     Error: 0.0334544051697
#     Fitness: 0.00363043220931
#     Experience: 110
#     Action Set Size: 70.40546508161884
#     Numerosity: 1
# 100#####0#0 => False
#     Time Stamp: 9950
#     Average Reward: 0.6
#     Error: 0.336666666667
#     Fitness: 0.00363233693823
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #01#0##1#01 => False
#     Time Stamp: 9879
#     Average Reward: 0.959698168811
#     Error: 0.120233796379
#     Fitness: 0.00365228937818
#     Experience: 19
#     Action Set Size: 43.30886845401595
#     Numerosity: 1
# #11######00 => False
#     Time Stamp: 9951
#     Average Reward: 0.946570485286
#     Error: 0.133573786784
#     Fitness: 0.00376805868433
#     Experience: 13
#     Action Set Size: 65.81265047317709
#     Numerosity: 1
# #####0##### => False
#     Time Stamp: 9991
#     Average Reward: 0.743893793181
#     Error: 0.354382623443
#     Fitness: 0.00390450677656
#     Experience: 19
#     Action Set Size: 48.84023632278992
#     Numerosity: 1
# ##0##1#1### => True
#     Time Stamp: 9995
#     Average Reward: 0.798967474574
#     Error: 0.282688684364
#     Fitness: 0.00394696414202
#     Experience: 69
#     Action Set Size: 62.143379029300434
#     Numerosity: 1
# 0#0#0111### => True
#     Time Stamp: 9844
#     Average Reward: 0.773752451257
#     Error: 0.332092012975
#     Fitness: 0.00403309503099
#     Experience: 28
#     Action Set Size: 54.434557064905725
#     Numerosity: 1
# ##1#1##00## => False
#     Time Stamp: 9990
#     Average Reward: 0.779690538011
#     Error: 0.274395944934
#     Fitness: 0.00407570868744
#     Experience: 37
#     Action Set Size: 61.982964673762446
#     Numerosity: 1
# ####00##### => False
#     Time Stamp: 9991
#     Average Reward: 0.764227703013
#     Error: 0.334519041174
#     Fitness: 0.00409374124849
#     Experience: 127
#     Action Set Size: 41.49119457064244
#     Numerosity: 1
# ##1#0####00 => False
#     Time Stamp: 9798
#     Average Reward: 0.864298363405
#     Error: 0.250034194874
#     Fitness: 0.00418706178537
#     Experience: 33
#     Action Set Size: 45.09502909618019
#     Numerosity: 1
# ##0####1##0 => True
#     Time Stamp: 9980
#     Average Reward: 0.838941900653
#     Error: 0.287154754919
#     Fitness: 0.00424232023205
#     Experience: 23
#     Action Set Size: 51.0984487626182
#     Numerosity: 1
# ##1#00###1# => False
#     Time Stamp: 9959
#     Average Reward: 0.900262746031
#     Error: 0.216560131124
#     Fitness: 0.00429395007817
#     Experience: 27
#     Action Set Size: 43.21118556410489
#     Numerosity: 1
# ####10##### => True
#     Time Stamp: 9992
#     Average Reward: 0.901060072996
#     Error: 0.212577917301
#     Fitness: 0.00432043930138
#     Experience: 116
#     Action Set Size: 61.99513036102067
#     Numerosity: 1
# 0#00####### => False
#     Time Stamp: 9966
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.00434582724958
#     Experience: 1
#     Action Set Size: 57.0
#     Numerosity: 1
# 0101####0## => False
#     Time Stamp: 9894
#     Average Reward: 0.940686155767
#     Error: 0.129601562849
#     Fitness: 0.00439792435292
#     Experience: 34
#     Action Set Size: 45.7686741103986
#     Numerosity: 1
# ##1##1##1## => False
#     Time Stamp: 9986
#     Average Reward: 0.562474206162
#     Error: 0.423878037125
#     Fitness: 0.00447849301416
#     Experience: 43
#     Action Set Size: 44.5666120227021
#     Numerosity: 1
# 1#1###0##1# => True
#     Time Stamp: 9957
#     Average Reward: 0.716214689962
#     Error: 0.336385948211
#     Fitness: 0.00454435983962
#     Experience: 125
#     Action Set Size: 53.28147489170049
#     Numerosity: 1
# #1011####0# => False
#     Time Stamp: 9894
#     Average Reward: 0.870585950521
#     Error: 0.235348692839
#     Fitness: 0.00499281475271
#     Experience: 12
#     Action Set Size: 40.428446171875
#     Numerosity: 1
# 00#1##10### => True
#     Time Stamp: 9949
#     Average Reward: 0.985440963483
#     Error: 0.0514419290263
#     Fitness: 0.00502007625096
#     Experience: 21
#     Action Set Size: 81.1589910050886
#     Numerosity: 1
# ###1#11##1# => True
#     Time Stamp: 9980
#     Average Reward: 0.915678003407
#     Error: 0.193412358529
#     Fitness: 0.00508063302966
#     Experience: 48
#     Action Set Size: 64.50999617259991
#     Numerosity: 1
# ####01##### => True
#     Time Stamp: 9977
#     Average Reward: 0.716711563835
#     Error: 0.353693483298
#     Fitness: 0.00509629480574
#     Experience: 184
#     Action Set Size: 46.58153583046625
#     Numerosity: 1
# ##0#01#1### => True
#     Time Stamp: 9893
#     Average Reward: 0.722989487983
#     Error: 0.352373109108
#     Fitness: 0.0051444755403
#     Experience: 131
#     Action Set Size: 53.63313731629094
#     Numerosity: 1
# 00#1###1### => True
#     Time Stamp: 9940
#     Average Reward: 0.833333333333
#     Error: 0.241666666667
#     Fitness: 0.00519290123857
#     Experience: 6
#     Action Set Size: 84.16666666666667
#     Numerosity: 1
# #1#######0# => False
#     Time Stamp: 9951
#     Average Reward: 0.997099299523
#     Error: 0.0152956922249
#     Fitness: 0.0052409798202
#     Experience: 620
#     Action Set Size: 55.58215566089743
#     Numerosity: 1
# 1###0##0##0 => False
#     Time Stamp: 9911
#     Average Reward: 0.82188142954
#     Error: 0.280593109004
#     Fitness: 0.00525273998633
#     Experience: 64
#     Action Set Size: 49.92509104274943
#     Numerosity: 1
# 1####011#1# => True
#     Time Stamp: 9999
#     Average Reward: 0.98529185751
#     Error: 0.0504793227564
#     Fitness: 0.00532409548841
#     Experience: 43
#     Action Set Size: 69.07138555258348
#     Numerosity: 1
# 1######0#0# => False
#     Time Stamp: 9986
#     Average Reward: 0.843397489739
#     Error: 0.200441760286
#     Fitness: 0.00542029573172
#     Experience: 42
#     Action Set Size: 55.10809720723768
#     Numerosity: 1
# #####1#1#1# => True
#     Time Stamp: 9995
#     Average Reward: 0.792203013525
#     Error: 0.330716856518
#     Fitness: 0.00550240261329
#     Experience: 89
#     Action Set Size: 60.569991343808525
#     Numerosity: 1
# 11####0##0# => False
#     Time Stamp: 9951
#     Average Reward: 0.967910937151
#     Error: 0.0953751251401
#     Fitness: 0.00555779181203
#     Experience: 30
#     Action Set Size: 62.318462051224785
#     Numerosity: 1
# ###1#####1# => True
#     Time Stamp: 9999
#     Average Reward: 0.857261779452
#     Error: 0.25119430759
#     Fitness: 0.00565658233271
#     Experience: 236
#     Action Set Size: 56.60795053133551
#     Numerosity: 1
# 0###01##### => True
#     Time Stamp: 9977
#     Average Reward: 0.633915510083
#     Error: 0.421833078562
#     Fitness: 0.0056799404496
#     Experience: 327
#     Action Set Size: 33.480198614294835
#     Numerosity: 1
# #######0### => False
#     Time Stamp: 9991
#     Average Reward: 0.703553852122
#     Error: 0.341291380751
#     Fitness: 0.00608988942412
#     Experience: 413
#     Action Set Size: 49.178276670411506
#     Numerosity: 1
# ##0#0#####1 => True
#     Time Stamp: 9981
#     Average Reward: 0.800927678069
#     Error: 0.288137955741
#     Fitness: 0.00640803039897
#     Experience: 156
#     Action Set Size: 56.22154089516114
#     Numerosity: 1
# #11#####000 => False
#     Time Stamp: 9840
#     Average Reward: 0.849722776752
#     Error: 0.281058333925
#     Fitness: 0.00644909639423
#     Experience: 30
#     Action Set Size: 74.18726046280655
#     Numerosity: 1
# 10##0###0## => False
#     Time Stamp: 9932
#     Average Reward: 0.960624811121
#     Error: 0.103991186899
#     Fitness: 0.00650338472846
#     Experience: 47
#     Action Set Size: 55.02256906949714
#     Numerosity: 1
# ###1#11###0 => True
#     Time Stamp: 9980
#     Average Reward: 0.862323324557
#     Error: 0.262164975866
#     Fitness: 0.00674068451201
#     Experience: 18
#     Action Set Size: 68.84779944920766
#     Numerosity: 1
# #10##0010## => False
#     Time Stamp: 9655
#     Average Reward: 0.8
#     Error: 0.223333333333
#     Fitness: 0.0067754233475
#     Experience: 5
#     Action Set Size: 51.8
#     Numerosity: 1
# ##1#1##0##0 => False
#     Time Stamp: 9990
#     Average Reward: 0.726969960256
#     Error: 0.33956676822
#     Fitness: 0.00678319900409
#     Experience: 18
#     Action Set Size: 62.2262138756591
#     Numerosity: 1
# #1#####10#1 => True
#     Time Stamp: 9995
#     Average Reward: 0.756110572241
#     Error: 0.289317788557
#     Fitness: 0.00711506384844
#     Experience: 43
#     Action Set Size: 64.31433015049312
#     Numerosity: 1
# ###101####1 => True
#     Time Stamp: 9949
#     Average Reward: 0.787787046953
#     Error: 0.26468050925
#     Fitness: 0.00711623420069
#     Experience: 28
#     Action Set Size: 52.88802580921725
#     Numerosity: 1
# ##0111##1## => True
#     Time Stamp: 9702
#     Average Reward: 0.952882277018
#     Error: 0.114384147461
#     Fitness: 0.00715030074807
#     Experience: 22
#     Action Set Size: 53.23114932255859
#     Numerosity: 1
# 0###01#1### => True
#     Time Stamp: 9893
#     Average Reward: 0.51935221502
#     Error: 0.447936837865
#     Fitness: 0.0071590287172
#     Experience: 72
#     Action Set Size: 39.85550969913246
#     Numerosity: 1
# ##1#0###000 => False
#     Time Stamp: 9798
#     Average Reward: 0.791784605068
#     Error: 0.315763628715
#     Fitness: 0.00723705134016
#     Experience: 25
#     Action Set Size: 49.84925537561351
#     Numerosity: 1
# 00##00##### => False
#     Time Stamp: 9984
#     Average Reward: 0.751083596273
#     Error: 0.308908092244
#     Fitness: 0.0072920692443
#     Experience: 33
#     Action Set Size: 47.78890321046761
#     Numerosity: 1
# #0#####0##0 => True
#     Time Stamp: 9992
#     Average Reward: 0.835493520458
#     Error: 0.265799448239
#     Fitness: 0.00746727746704
#     Experience: 26
#     Action Set Size: 57.44052885968491
#     Numerosity: 1
# #1######### => False
#     Time Stamp: 9991
#     Average Reward: 0.722401894846
#     Error: 0.333521488397
#     Fitness: 0.00762335156809
#     Experience: 59
#     Action Set Size: 47.300121146044766
#     Numerosity: 1
# ###000#1##1 => True
#     Time Stamp: 9659
#     Average Reward: 0.731953863526
#     Error: 0.346125808055
#     Fitness: 0.00779839039531
#     Experience: 33
#     Action Set Size: 57.00033920845386
#     Numerosity: 1
# 10##1###00# => False
#     Time Stamp: 9925
#     Average Reward: 0.929007220414
#     Error: 0.162792367166
#     Fitness: 0.00783949114367
#     Experience: 58
#     Action Set Size: 51.31837332786458
#     Numerosity: 1
# 00#1#####0# => True
#     Time Stamp: 9992
#     Average Reward: 0.997295542329
#     Error: 0.0144677906007
#     Fitness: 0.00785730819351
#     Experience: 76
#     Action Set Size: 77.85015246930475
#     Numerosity: 1
# ##0##0##### => False
#     Time Stamp: 9991
#     Average Reward: 0.600141360985
#     Error: 0.402254869325
#     Fitness: 0.00793753826941
#     Experience: 297
#     Action Set Size: 39.88454461795946
#     Numerosity: 1
# #0##0##0### => False
#     Time Stamp: 9986
#     Average Reward: 0.825083420566
#     Error: 0.238030483373
#     Fitness: 0.00803670104077
#     Experience: 270
#     Action Set Size: 52.92606898241307
#     Numerosity: 1
# 0##1####01# => True
#     Time Stamp: 9980
#     Average Reward: 0.808478665546
#     Error: 0.255092162061
#     Fitness: 0.0083843504939
#     Experience: 39
#     Action Set Size: 66.47726025381279
#     Numerosity: 1
# ####0001#1# => False
#     Time Stamp: 9984
#     Average Reward: 0.776314020521
#     Error: 0.276137904523
#     Fitness: 0.00839932973647
#     Experience: 16
#     Action Set Size: 42.350095179285674
#     Numerosity: 1
# #########0# => False
#     Time Stamp: 9986
#     Average Reward: 0.823947080725
#     Error: 0.233264965687
#     Fitness: 0.00854368018529
#     Experience: 1139
#     Action Set Size: 51.064690428808554
#     Numerosity: 1
# #010######1 => False
#     Time Stamp: 9986
#     Average Reward: 0.589373177083
#     Error: 0.369985550347
#     Fitness: 0.0088813695124
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #1#####1#0# => False
#     Time Stamp: 9894
#     Average Reward: 0.97205380232
#     Error: 0.0819453611039
#     Fitness: 0.00960246106901
#     Experience: 164
#     Action Set Size: 47.38931063668816
#     Numerosity: 1
# 10######00# => False
#     Time Stamp: 9932
#     Average Reward: 0.976374370714
#     Error: 0.0762145208812
#     Fitness: 0.0101306655485
#     Experience: 53
#     Action Set Size: 53.47227208278813
#     Numerosity: 1
# 0##1####011 => True
#     Time Stamp: 9901
#     Average Reward: 0.661425242187
#     Error: 0.377885372873
#     Fitness: 0.0101806852395
#     Experience: 12
#     Action Set Size: 48.872857184895835
#     Numerosity: 1
# 01##10##0## => False
#     Time Stamp: 9990
#     Average Reward: 0.848581154862
#     Error: 0.134625718388
#     Fitness: 0.0104832969841
#     Experience: 72
#     Action Set Size: 52.9448499497034
#     Numerosity: 1
# 100#0##1##1 => True
#     Time Stamp: 9981
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0106166487886
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# ##0#0011### => True
#     Time Stamp: 9981
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0106166487886
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 0#1######11 => True
#     Time Stamp: 9978
#     Average Reward: 0.508786340695
#     Error: 0.416334045053
#     Fitness: 0.0108365788379
#     Experience: 56
#     Action Set Size: 45.68049203567643
#     Numerosity: 1
# 1#1#0#####0 => True
#     Time Stamp: 9999
#     Average Reward: 0.600450006664
#     Error: 0.432793033095
#     Fitness: 0.0108741857117
#     Experience: 26
#     Action Set Size: 46.01656085904273
#     Numerosity: 1
# ##0##0010## => False
#     Time Stamp: 9984
#     Average Reward: 0.708557274057
#     Error: 0.343799075034
#     Fitness: 0.0113268974531
#     Experience: 32
#     Action Set Size: 50.21291739976621
#     Numerosity: 1
# 0##0###1### => True
#     Time Stamp: 9978
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0113434221076
#     Experience: 2
#     Action Set Size: 61.5
#     Numerosity: 1
# 110011#1### => True
#     Time Stamp: 9995
#     Average Reward: 0.858840809896
#     Error: 0.23191940178
#     Fitness: 0.01145618336
#     Experience: 12
#     Action Set Size: 59.717206846354166
#     Numerosity: 1
# 11####1###1 => True
#     Time Stamp: 9952
#     Average Reward: 0.944418278755
#     Error: 0.129857716459
#     Fitness: 0.0116122623568
#     Experience: 32
#     Action Set Size: 70.91703555239792
#     Numerosity: 1
# ###00#####1 => True
#     Time Stamp: 9944
#     Average Reward: 0.735043632903
#     Error: 0.383460812637
#     Fitness: 0.0116390449775
#     Experience: 21
#     Action Set Size: 51.01271641277773
#     Numerosity: 1
# 11####01#0# => False
#     Time Stamp: 9867
#     Average Reward: 0.932445057334
#     Error: 0.152448987283
#     Fitness: 0.0117359025125
#     Experience: 16
#     Action Set Size: 54.43884844759585
#     Numerosity: 1
# 0##11####11 => True
#     Time Stamp: 9870
#     Average Reward: 0.5
#     Error: 0.25
#     Fitness: 0.0118782540355
#     Experience: 2
#     Action Set Size: 52.5
#     Numerosity: 1
# ##1#1#1#### => True
#     Time Stamp: 9978
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0120358966325
#     Experience: 2
#     Action Set Size: 83.0
#     Numerosity: 1
# 0##1#####11 => True
#     Time Stamp: 9901
#     Average Reward: 0.719349037902
#     Error: 0.297742992813
#     Fitness: 0.0121231410047
#     Experience: 51
#     Action Set Size: 51.663017965191365
#     Numerosity: 1
# 1##1###1#10 => False
#     Time Stamp: 9975
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0121931570368
#     Experience: 2
#     Action Set Size: 64.5
#     Numerosity: 1
# ##1#11##1## => False
#     Time Stamp: 9951
#     Average Reward: 0.625659225968
#     Error: 0.405041651629
#     Fitness: 0.0139256878995
#     Experience: 40
#     Action Set Size: 44.00076956656807
#     Numerosity: 1
# #1##1###### => False
#     Time Stamp: 9990
#     Average Reward: 0.85
#     Error: 0.1275
#     Fitness: 0.0143031657236
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# ##00#0##### => False
#     Time Stamp: 9966
#     Average Reward: 0.761386661777
#     Error: 0.289186486371
#     Fitness: 0.0144431429293
#     Experience: 16
#     Action Set Size: 45.528613774454634
#     Numerosity: 1
# #101#00###1 => False
#     Time Stamp: 9745
#     Average Reward: 0.75
#     Error: 0.270833333333
#     Fitness: 0.0145367892584
#     Experience: 4
#     Action Set Size: 48.25
#     Numerosity: 1
# #10##0####1 => False
#     Time Stamp: 9991
#     Average Reward: 0.81689829676
#     Error: 0.250875080923
#     Fitness: 0.0145878968974
#     Experience: 142
#     Action Set Size: 47.649767711069885
#     Numerosity: 1
# 0##11##1### => True
#     Time Stamp: 9980
#     Average Reward: 0.75
#     Error: 0.270833333333
#     Fitness: 0.0154621437338
#     Experience: 4
#     Action Set Size: 71.0
#     Numerosity: 1
# 1##1####0#0 => False
#     Time Stamp: 9975
#     Average Reward: 0.825997916667
#     Error: 0.279853350694
#     Fitness: 0.0161168720307
#     Experience: 10
#     Action Set Size: 63.80451041666666
#     Numerosity: 1
# ##010#####1 => True
#     Time Stamp: 9981
#     Average Reward: 0.796570485286
#     Error: 0.236140013251
#     Fitness: 0.0166337718343
#     Experience: 13
#     Action Set Size: 58.35098098151042
#     Numerosity: 1
# 1#######0## => False
#     Time Stamp: 9975
#     Average Reward: 0.889998057943
#     Error: 0.207641761102
#     Fitness: 0.0169586816197
#     Experience: 13
#     Action Set Size: 56.30345071041667
#     Numerosity: 1
# 00#11#####1 => True
#     Time Stamp: 9914
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0174053483141
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 11#####1#1# => True
#     Time Stamp: 9995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0180043971036
#     Experience: 4
#     Action Set Size: 77.75
#     Numerosity: 1
# ##00#0#1### => False
#     Time Stamp: 9935
#     Average Reward: 0.699293551946
#     Error: 0.30705600852
#     Fitness: 0.0183867694666
#     Experience: 42
#     Action Set Size: 41.73163380467108
#     Numerosity: 1
# 00##01###1# => True
#     Time Stamp: 9977
#     Average Reward: 0.815785627033
#     Error: 0.205799373674
#     Fitness: 0.0184392424302
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 0#01#11#### => True
#     Time Stamp: 9980
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0185440252781
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 11#01##1##1 => True
#     Time Stamp: 9995
#     Average Reward: 0.954584912493
#     Error: 0.120349981892
#     Fitness: 0.0187658661628
#     Experience: 14
#     Action Set Size: 81.38463881347006
#     Numerosity: 1
# 0#0#100#0## => False
#     Time Stamp: 9655
#     Average Reward: 0.999137392385
#     Error: 0.00525181570491
#     Fitness: 0.0194030841564
#     Experience: 90
#     Action Set Size: 61.93098146102113
#     Numerosity: 1
# 0###0111#1# => True
#     Time Stamp: 9844
#     Average Reward: 0.686736818026
#     Error: 0.379482495748
#     Fitness: 0.0207629782562
#     Experience: 19
#     Action Set Size: 53.61039522263242
#     Numerosity: 1
# ####0111##1 => True
#     Time Stamp: 9705
#     Average Reward: 0.660208525859
#     Error: 0.381582625702
#     Fitness: 0.0214422256254
#     Experience: 21
#     Action Set Size: 51.850908126406146
#     Numerosity: 1
# ##0#100#010 => False
#     Time Stamp: 9366
#     Average Reward: 0.670880208333
#     Error: 0.331270086806
#     Fitness: 0.0218659721712
#     Experience: 10
#     Action Set Size: 41.94136354166667
#     Numerosity: 1
# 0#001###### => False
#     Time Stamp: 9966
#     Average Reward: 0.863916519404
#     Error: 0.201643086386
#     Fitness: 0.0227332877975
#     Experience: 51
#     Action Set Size: 48.24604963059176
#     Numerosity: 1
# #00#1###1## => False
#     Time Stamp: 9966
#     Average Reward: 0.889998057943
#     Error: 0.190722414776
#     Fitness: 0.0237933384526
#     Experience: 13
#     Action Set Size: 47.84299394101562
#     Numerosity: 1
# 111####1#0# => True
#     Time Stamp: 9952
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0250794928474
#     Experience: 25
#     Action Set Size: 83.06193664102973
#     Numerosity: 1
# 11#####101# => True
#     Time Stamp: 9995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0253180369545
#     Experience: 15
#     Action Set Size: 70.76723785377247
#     Numerosity: 1
# 1#100#1#### => True
#     Time Stamp: 9881
#     Average Reward: 0.666666666667
#     Error: 0.277777777778
#     Fitness: 0.0253920649519
#     Experience: 3
#     Action Set Size: 54.0
#     Numerosity: 1
# 0##1#0##### => True
#     Time Stamp: 9992
#     Average Reward: 0.759166666667
#     Error: 0.321111111111
#     Fitness: 0.0256229563012
#     Experience: 8
#     Action Set Size: 59.41583333333334
#     Numerosity: 1
# #11###01#0# => False
#     Time Stamp: 9775
#     Average Reward: 0.937141747396
#     Error: 0.126764142752
#     Fitness: 0.0264008866081
#     Experience: 12
#     Action Set Size: 76.146872734375
#     Numerosity: 1
# #00#1#00#0# => False
#     Time Stamp: 9966
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0266848437759
#     Experience: 3
#     Action Set Size: 54.333333333333336
#     Numerosity: 1
# #1##0#####1 => True
#     Time Stamp: 9944
#     Average Reward: 0.827764665557
#     Error: 0.244258791374
#     Fitness: 0.0268892127712
#     Experience: 78
#     Action Set Size: 58.57179821116849
#     Numerosity: 1
# #0##0##10## => False
#     Time Stamp: 9984
#     Average Reward: 0.708333333333
#     Error: 0.311666666667
#     Fitness: 0.0277158202373
#     Experience: 7
#     Action Set Size: 43.625
#     Numerosity: 1
# ####0#0##0# => False
#     Time Stamp: 9986
#     Average Reward: 0.636767176812
#     Error: 0.309305226922
#     Fitness: 0.0278231137186
#     Experience: 73
#     Action Set Size: 45.6949624319648
#     Numerosity: 1
# ###1#1#1### => True
#     Time Stamp: 9980
#     Average Reward: 0.753563238465
#     Error: 0.257444891002
#     Fitness: 0.0295585590968
#     Experience: 21
#     Action Set Size: 60.43381572277162
#     Numerosity: 1
# #0#10###### => False
#     Time Stamp: 9984
#     Average Reward: 0.833333333333
#     Error: 0.186111111111
#     Fitness: 0.0296412248723
#     Experience: 6
#     Action Set Size: 51.5
#     Numerosity: 1
# 1#0011#1### => True
#     Time Stamp: 9995
#     Average Reward: 0.926049114583
#     Error: 0.11708890191
#     Fitness: 0.0297099420423
#     Experience: 11
#     Action Set Size: 58.77121276041667
#     Numerosity: 1
# 10#0###0### => False
#     Time Stamp: 9986
#     Average Reward: 0.613669093835
#     Error: 0.351679598454
#     Fitness: 0.0305318569115
#     Experience: 78
#     Action Set Size: 51.20837871657836
#     Numerosity: 1
# #01#####01# => True
#     Time Stamp: 9940
#     Average Reward: 0.308177746703
#     Error: 0.361233217522
#     Fitness: 0.0305971806007
#     Experience: 52
#     Action Set Size: 51.95137483087847
#     Numerosity: 1
# 1000#####1# => False
#     Time Stamp: 9757
#     Average Reward: 0.926049114583
#     Error: 0.162691947917
#     Fitness: 0.0306809501845
#     Experience: 11
#     Action Set Size: 58.78818432291667
#     Numerosity: 1
# 0#1101##### => True
#     Time Stamp: 9792
#     Average Reward: 0.575
#     Error: 0.380138888889
#     Fitness: 0.0315620076486
#     Experience: 7
#     Action Set Size: 50.18333333333333
#     Numerosity: 1
# 1#100###### => True
#     Time Stamp: 9882
#     Average Reward: 0.729773074481
#     Error: 0.347568676971
#     Fitness: 0.0334606901225
#     Experience: 18
#     Action Set Size: 60.9340819080867
#     Numerosity: 1
# ##1####10#0 => False
#     Time Stamp: 9975
#     Average Reward: 0.833333333333
#     Error: 0.241666666667
#     Fitness: 0.0342942162006
#     Experience: 6
#     Action Set Size: 58.5
#     Numerosity: 1
# #1##1#00### => False
#     Time Stamp: 9951
#     Average Reward: 0.9216990625
#     Error: 0.113536359375
#     Fitness: 0.0343418020157
#     Experience: 11
#     Action Set Size: 72.199639375
#     Numerosity: 1
# 111####1#01 => True
#     Time Stamp: 9952
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0359481816726
#     Experience: 100
#     Action Set Size: 83.04173827242293
#     Numerosity: 1
# 01#0##01000 => False
#     Time Stamp: 9589
#     Average Reward: 0.8725
#     Error: 0.1275
#     Fitness: 0.0363947623659
#     Experience: 10
#     Action Set Size: 58.618257291666666
#     Numerosity: 1
# ##1#1###0#0 => False
#     Time Stamp: 9990
#     Average Reward: 0.770145833333
#     Error: 0.291266666667
#     Fitness: 0.0364296332074
#     Experience: 9
#     Action Set Size: 62.142583333333334
#     Numerosity: 1
# 0#1#1###### => True
#     Time Stamp: 9992
#     Average Reward: 0.8
#     Error: 0.256666666667
#     Fitness: 0.0368018421748
#     Experience: 5
#     Action Set Size: 57.0
#     Numerosity: 1
# #101#0010## => False
#     Time Stamp: 9655
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0371635565678
#     Experience: 7
#     Action Set Size: 54.233333333333334
#     Numerosity: 1
# ######1#### => True
#     Time Stamp: 9999
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0376660910859
#     Experience: 5
#     Action Set Size: 73.2
#     Numerosity: 1
# #####11#### => True
#     Time Stamp: 9980
#     Average Reward: 0.865871323683
#     Error: 0.194156345563
#     Fitness: 0.0381130514388
#     Experience: 38
#     Action Set Size: 54.26347711964044
#     Numerosity: 1
# #00#1#0#101 => False
#     Time Stamp: 9793
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0381834606961
#     Experience: 4
#     Action Set Size: 51.25
#     Numerosity: 1
# 0#001###01# => False
#     Time Stamp: 9749
#     Average Reward: 0.897645833333
#     Error: 0.194472916667
#     Fitness: 0.0414751512181
#     Experience: 9
#     Action Set Size: 52.42772916666667
#     Numerosity: 1
# 00##1##1### => True
#     Time Stamp: 9940
#     Average Reward: 0.936497986328
#     Error: 0.132215413799
#     Fitness: 0.0436099227421
#     Experience: 24
#     Action Set Size: 80.20656200160506
#     Numerosity: 1
# ##011###### => True
#     Time Stamp: 9980
#     Average Reward: 0.865246956484
#     Error: 0.213051086498
#     Fitness: 0.0442373444497
#     Experience: 24
#     Action Set Size: 59.251517897094786
#     Numerosity: 1
# 01#1####10# => False
#     Time Stamp: 9797
#     Average Reward: 0.876283974993
#     Error: 0.192255844386
#     Fitness: 0.0462616147818
#     Experience: 14
#     Action Set Size: 49.24737565940755
#     Numerosity: 1
# 1#1###0#0#0 => False
#     Time Stamp: 9975
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0473449959325
#     Experience: 19
#     Action Set Size: 78.61181566622766
#     Numerosity: 1
# #0#10####10 => False
#     Time Stamp: 9924
#     Average Reward: 0.686916666667
#     Error: 0.366869444444
#     Fitness: 0.0484459457163
#     Experience: 9
#     Action Set Size: 45.77433333333334
#     Numerosity: 1
# 1#0#1100#0# => False
#     Time Stamp: 9822
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0500356671196
#     Experience: 3
#     Action Set Size: 49.333333333333336
#     Numerosity: 1
# ##0#01#1##0 => True
#     Time Stamp: 9844
#     Average Reward: 0.817939020521
#     Error: 0.257409827507
#     Fitness: 0.050677130337
#     Experience: 16
#     Action Set Size: 45.116339663495154
#     Numerosity: 1
# 1#1###0###0 => False
#     Time Stamp: 9975
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0556055054476
#     Experience: 4
#     Action Set Size: 72.25
#     Numerosity: 1
# 0#0101##### => False
#     Time Stamp: 9648
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.0558804646862
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #11#1#####0 => False
#     Time Stamp: 9990
#     Average Reward: 0.5
#     Error: 0.25
#     Fitness: 0.0593108945114
#     Experience: 2
#     Action Set Size: 57.5
#     Numerosity: 1
# 000101##### => True
#     Time Stamp: 9949
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0648330438207
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 110###0###0 => False
#     Time Stamp: 9911
#     Average Reward: 0.716666666667
#     Error: 0.31875
#     Fitness: 0.0677258495856
#     Experience: 7
#     Action Set Size: 32.55833333333333
#     Numerosity: 1
# 0##000##### => True
#     Time Stamp: 9937
# ...
#     Error: 0.274565948436
#     Fitness: 0.0497029636063
#     Experience: 35
#     Action Set Size: 50.140359296598554
#     Numerosity: 2
# 0#00#1##01# => False
#     Time Stamp: 9854
#     Average Reward: 0.708333333333
#     Error: 0.288055555556
#     Fitness: 0.0631563611382
#     Experience: 7
#     Action Set Size: 26.09166666666667
#     Numerosity: 2
# #0##0###0## => False
#     Time Stamp: 9984
#     Average Reward: 0.885387396054
#     Error: 0.149700745356
#     Fitness: 0.0692922447619
#     Experience: 90
#     Action Set Size: 51.170903742540396
#     Numerosity: 2
# #110##0#### => False
#     Time Stamp: 9951
#     Average Reward: 0.997519006874
#     Error: 0.012675853509
#     Fitness: 0.0697401287384
#     Experience: 66
#     Action Set Size: 65.56080109029502
#     Numerosity: 2
# ##010##1### => True
#     Time Stamp: 9981
#     Average Reward: 0.83458454957
#     Error: 0.168350943639
#     Fitness: 0.0710310844736
#     Experience: 23
#     Action Set Size: 56.197039456471806
#     Numerosity: 2
# #101#0##1#1 => False
#     Time Stamp: 9991
#     Average Reward: 0.820880208333
#     Error: 0.229955694444
#     Fitness: 0.0716432662847
#     Experience: 10
#     Action Set Size: 41.913692708333336
#     Numerosity: 2
# 11##1##1#11 => True
#     Time Stamp: 9995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0727851003458
#     Experience: 37
#     Action Set Size: 75.84595966466588
#     Numerosity: 2
# #000####### => False
#     Time Stamp: 9966
#     Average Reward: 0.812670136199
#     Error: 0.218329526999
#     Fitness: 0.0759276876256
#     Experience: 178
#     Action Set Size: 50.810191117874744
#     Numerosity: 2
# 00#1#110### => True
#     Time Stamp: 9949
#     Average Reward: 0.954584912493
#     Error: 0.0983993562641
#     Fitness: 0.0838103238083
#     Experience: 14
#     Action Set Size: 75.49783527692057
#     Numerosity: 2
# 11#####1011 => True
#     Time Stamp: 9995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0984428968002
#     Experience: 35
#     Action Set Size: 68.37520385781701
#     Numerosity: 2
# ##1#1###### => False
#     Time Stamp: 9990
#     Average Reward: 0.8725
#     Error: 0.1275
#     Fitness: 0.121576911721
#     Experience: 10
#     Action Set Size: 63.45813541666666
#     Numerosity: 2
# 1#010##10## => True
#     Time Stamp: 9981
#     Average Reward: 0.85
#     Error: 0.1275
#     Fitness: 0.129157115478
#     Experience: 7
#     Action Set Size: 64.38333333333333
#     Numerosity: 2
# 0#011##1### => True
#     Time Stamp: 9980
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.165728328527
#     Experience: 13
#     Action Set Size: 74.38417107552084
#     Numerosity: 2
# ###1011##1# => True
#     Time Stamp: 9844
#     Average Reward: 0.879583333333
#     Error: 0.136472222222
#     Fitness: 0.167050146566
#     Experience: 8
#     Action Set Size: 66.14833333333334
#     Numerosity: 2
# ##00#01##0# => True
#     Time Stamp: 9338
#     Average Reward: 0.102354166667
#     Error: 0.160354861111
#     Fitness: 0.212884220181
#     Experience: 9
#     Action Set Size: 26.413791666666665
#     Numerosity: 2
# 100#0#110## => True
#     Time Stamp: 9981
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.233492910555
#     Experience: 20
#     Action Set Size: 59.1543537778242
#     Numerosity: 2
# ##1###0##0# => False
#     Time Stamp: 9986
#     Average Reward: 0.806238531247
#     Error: 0.245524988382
#     Fitness: 0.00179076767664
#     Experience: 87
#     Action Set Size: 66.85616369508848
#     Numerosity: 3
# ##1####1### => False
#     Time Stamp: 9975
#     Average Reward: 0.962949915852
#     Error: 0.105855336307
#     Fitness: 0.00383329838842
#     Experience: 41
#     Action Set Size: 48.25710172894133
#     Numerosity: 3
# 1#1#######0 => True
#     Time Stamp: 9999
#     Average Reward: 0.681700985439
#     Error: 0.419505039165
#     Fitness: 0.00503932444449
#     Experience: 41
#     Action Set Size: 46.61245378738569
#     Numerosity: 3
# 1#001##1### => True
#     Time Stamp: 9995
#     Average Reward: 0.988561745666
#     Error: 0.0444472130854
#     Fitness: 0.00546383723801
#     Experience: 57
#     Action Set Size: 66.15032741920143
#     Numerosity: 3
# 0##1####### => True
#     Time Stamp: 9992
#     Average Reward: 0.876587228845
#     Error: 0.236351448242
#     Fitness: 0.00792084549862
#     Experience: 119
#     Action Set Size: 62.200210892100145
#     Numerosity: 3
# 00##1###### => True
#     Time Stamp: 9992
#     Average Reward: 0.988079558194
#     Error: 0.040836728487
#     Fitness: 0.00809969908696
#     Experience: 67
#     Action Set Size: 75.09595248770732
#     Numerosity: 3
# 0###0111### => True
#     Time Stamp: 9844
#     Average Reward: 0.633819789664
#     Error: 0.431787974316
#     Fitness: 0.00869390387933
#     Experience: 48
#     Action Set Size: 50.402619558877305
#     Numerosity: 3
# 00#1####### => True
#     Time Stamp: 9992
#     Average Reward: 0.97846010406
#     Error: 0.0579326354988
#     Fitness: 0.00921950615678
#     Experience: 69
#     Action Set Size: 73.09730382839
#     Numerosity: 3
# ##0###11### => True
#     Time Stamp: 9981
#     Average Reward: 0.968994894463
#     Error: 0.0961256192792
#     Fitness: 0.00954987304349
#     Experience: 98
#     Action Set Size: 71.45040699483317
#     Numerosity: 3
# 1######0##0 => False
#     Time Stamp: 9951
#     Average Reward: 0.910827448874
#     Error: 0.192250898645
#     Fitness: 0.00954988712931
#     Experience: 167
#     Action Set Size: 66.19231123399648
#     Numerosity: 3
# ##1#01#0### => False
#     Time Stamp: 9986
#     Average Reward: 0.642733934935
#     Error: 0.374760424394
#     Fitness: 0.0101950036892
#     Experience: 37
#     Action Set Size: 42.286686378164326
#     Numerosity: 3
# ##0####1### => True
#     Time Stamp: 9995
#     Average Reward: 0.816369796498
#     Error: 0.264576498493
#     Fitness: 0.0103157748404
#     Experience: 286
#     Action Set Size: 63.652290463691735
#     Numerosity: 3
# #01#0##1#1# => False
#     Time Stamp: 9959
#     Average Reward: 0.93291230349
#     Error: 0.152139752914
#     Fitness: 0.0113711370114
#     Experience: 42
#     Action Set Size: 51.43904449517965
#     Numerosity: 3
# 1#1#0#####0 => False
#     Time Stamp: 9895
#     Average Reward: 0.960561055982
#     Error: 0.114217856598
#     Fitness: 0.0132464906558
#     Experience: 75
#     Action Set Size: 48.18568600166836
#     Numerosity: 3
# ###001#0### => False
#     Time Stamp: 9986
#     Average Reward: 0.814631165253
#     Error: 0.225081991513
#     Fitness: 0.014389645391
#     Experience: 30
#     Action Set Size: 48.77253717797045
#     Numerosity: 3
# ####0##0### => True
#     Time Stamp: 9977
#     Average Reward: 0.789894399927
#     Error: 0.310527124626
#     Fitness: 0.0178123613187
#     Experience: 250
#     Action Set Size: 36.70688554136097
#     Numerosity: 3
# 1#0####0### => False
#     Time Stamp: 9932
#     Average Reward: 0.739553845122
#     Error: 0.31167200992
#     Fitness: 0.0270450954499
#     Experience: 148
#     Action Set Size: 46.425226336650155
#     Numerosity: 3
# ##1##110### => True
#     Time Stamp: 9977
#     Average Reward: 0.712383796649
#     Error: 0.335630814366
#     Fitness: 0.0299488610889
#     Experience: 102
#     Action Set Size: 54.508013266616445
#     Numerosity: 3
# 11#######01 => True
#     Time Stamp: 9952
#     Average Reward: 0.650652250644
#     Error: 0.371865156523
#     Fitness: 0.033860632644
#     Experience: 22
#     Action Set Size: 64.6063703511635
#     Numerosity: 3
# #0##0##1#1# => False
#     Time Stamp: 9984
#     Average Reward: 0.576035440323
#     Error: 0.409553783249
#     Fitness: 0.038188274672
#     Experience: 26
#     Action Set Size: 42.11464350444426
#     Numerosity: 3
# #11##111### => True
#     Time Stamp: 9978
#     Average Reward: 0.973034700804
#     Error: 0.0713272545402
#     Fitness: 0.044195372908
#     Experience: 44
#     Action Set Size: 63.99166134691648
#     Numerosity: 3
# ##010###### => True
#     Time Stamp: 9981
#     Average Reward: 0.838276922366
#     Error: 0.171023124279
#     Fitness: 0.0670421435521
#     Experience: 45
#     Action Set Size: 50.59801666553398
#     Numerosity: 3
# 010##0####1 => False
#     Time Stamp: 9991
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0936852862763
#     Experience: 128
#     Action Set Size: 58.84431693038803
#     Numerosity: 3
# #######1### => True
#     Time Stamp: 9999
#     Average Reward: 0.879583333333
#     Error: 0.136472222222
#     Fitness: 0.110999169131
#     Experience: 8
#     Action Set Size: 67.65458333333333
#     Numerosity: 3
# 1100#0##### => True
#     Time Stamp: 9944
#     Average Reward: 0.974898513447
#     Error: 0.0627537163836
#     Fitness: 0.138494122171
#     Experience: 18
#     Action Set Size: 51.00778481664209
#     Numerosity: 3
# 011###0##0# => False
#     Time Stamp: 9910
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.238110314261
#     Experience: 8
#     Action Set Size: 66.01625
#     Numerosity: 3
# 1#1#####11# => True
#     Time Stamp: 9999
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.260795258768
#     Experience: 11
#     Action Set Size: 67.59016838541666
#     Numerosity: 3
# 1#0###1#11# => True
#     Time Stamp: 9944
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.337278775738
#     Experience: 4
#     Action Set Size: 45.25
#     Numerosity: 3
# 0#0#01##### => False
#     Time Stamp: 9854
#     Average Reward: 0.270416666667
#     Error: 0.227847222222
#     Fitness: 0.343175960395
#     Experience: 8
#     Action Set Size: 28.359583333333333
#     Numerosity: 3
# ##0111#1### => True
#     Time Stamp: 9980
#     Average Reward: 0.990358163457
#     Error: 0.0371400042506
#     Fitness: 0.00720818461692
#     Experience: 97
#     Action Set Size: 66.67352918025917
#     Numerosity: 4
# 1#1#1###0## => False
#     Time Stamp: 9975
#     Average Reward: 0.991375098892
#     Error: 0.0346473167227
#     Fitness: 0.0129864472633
#     Experience: 69
#     Action Set Size: 63.9599765594182
#     Numerosity: 4
# 0####1#1### => True
#     Time Stamp: 9980
#     Average Reward: 0.722241394254
#     Error: 0.395307602647
#     Fitness: 0.0141098734269
#     Experience: 85
#     Action Set Size: 56.63252046272232
#     Numerosity: 4
# 0#011###### => True
#     Time Stamp: 9980
#     Average Reward: 0.988830257678
#     Error: 0.0364654455127
#     Fitness: 0.0229026626156
#     Experience: 127
#     Action Set Size: 71.11037517829409
#     Numerosity: 4
# #0####100## => False
#     Time Stamp: 9925
#     Average Reward: 0.97788269639
#     Error: 0.0608238013441
#     Fitness: 0.159422197759
#     Experience: 39
#     Action Set Size: 52.70310922948782
#     Numerosity: 4
# 110#1#0##0# => False
#     Time Stamp: 9867
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.515300923856
#     Experience: 29
#     Action Set Size: 34.247285408891905
#     Numerosity: 4
# 00010###### => True
#     Time Stamp: 9949
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.648330438207
#     Experience: 9
#     Action Set Size: 50.899249999999995
#     Numerosity: 4
# #01#0###### => False
#     Time Stamp: 9986
#     Average Reward: 0.788444444059
#     Error: 0.267761608197
#     Fitness: 0.0142543203312
#     Experience: 438
#     Action Set Size: 46.86893120315343
#     Numerosity: 5
# 11100###### => True
#     Time Stamp: 9882
#     Average Reward: 0.974898513447
#     Error: 0.0627537163836
#     Fitness: 0.0210998687675
#     Experience: 67
#     Action Set Size: 75.91380483126785
#     Numerosity: 5
# #101#0####1 => False
#     Time Stamp: 9991
#     Average Reward: 0.764185339538
#     Error: 0.30281908701
#     Fitness: 0.0764091693981
#     Experience: 56
#     Action Set Size: 42.511476250237344
#     Numerosity: 5
# 1#0#1#0#10# => False
#     Time Stamp: 9867
#     Average Reward: 0.898414236505
#     Error: 0.149102116835
#     Fitness: 0.0886787321739
#     Experience: 39
#     Action Set Size: 36.4585007949573
#     Numerosity: 5
# ########### => True
#     Time Stamp: 9999
#     Average Reward: 0.879755646205
#     Error: 0.206041803876
#     Fitness: 0.0117787953629
#     Experience: 670
#     Action Set Size: 53.76830388998104
#     Numerosity: 6
# 11#0#0####1 => True
#     Time Stamp: 9952
#     Average Reward: 0.993375140617
#     Error: 0.0293190076964
#     Fitness: 0.0294395108056
#     Experience: 60
#     Action Set Size: 77.21882312491486
#     Numerosity: 6
# #01#0####1# => False
#     Time Stamp: 9959
#     Average Reward: 0.880034160891
#     Error: 0.193266183773
#     Fitness: 0.0346061413386
#     Experience: 106
#     Action Set Size: 48.43257658314333
#     Numerosity: 6
# #01#00##### => False
#     Time Stamp: 9959
#     Average Reward: 0.910052152312
#     Error: 0.153142664731
#     Fitness: 0.0472185757955
#     Experience: 76
#     Action Set Size: 48.974093502179315
#     Numerosity: 6
# 1######11## => True
#     Time Stamp: 9999
#     Average Reward: 0.996429520446
#     Error: 0.0153530620826
#     Fitness: 0.166650834496
#     Experience: 44
#     Action Set Size: 61.62403924202883
#     Numerosity: 6
# #0##00#10## => False
#     Time Stamp: 9984
#     Average Reward: 0.833333333333
#     Error: 0.138888888889
#     Fitness: 0.479433389089
#     Experience: 6
#     Action Set Size: 50.5
#     Numerosity: 6
# 0###00#1### => True
#     Time Stamp: 9937
#     Average Reward: 0.0870010416667
#     Error: 0.136301631944
#     Fitness: 0.617741031335
#     Experience: 10
#     Action Set Size: 22.956003125
#     Numerosity: 6
# 111#######0 => True
#     Time Stamp: 9920
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.905701065285
#     Experience: 22
#     Action Set Size: 41.69570622408637
#     Numerosity: 6
# 1######111# => True
#     Time Stamp: 9999
#     Average Reward: 0.999997619485
#     Error: 2.6308509955e-05
#     Fitness: 0.41312257704
#     Experience: 217
#     Action Set Size: 70.1472120468587
#     Numerosity: 7
# #000###0### => False
#     Time Stamp: 9966
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.284808858224
#     Experience: 32
#     Action Set Size: 59.31063059757272
#     Numerosity: 8
# #11###0##0# => False
#     Time Stamp: 9951
#     Average Reward: 0.923223906548
#     Error: 0.174259689889
#     Fitness: 0.0319105887993
#     Experience: 167
#     Action Set Size: 79.52690671071232
#     Numerosity: 9
# 0##000#1### => True
#     Time Stamp: 9937
#     Average Reward: 0.137533837507
#     Error: 0.198473860011
#     Fitness: 0.324095265114
#     Experience: 14
#     Action Set Size: 23.439174519772138
#     Numerosity: 10
# 1#0####101# => True
#     Time Stamp: 9995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.358898527743
#     Experience: 73
#     Action Set Size: 73.32951735156976
#     Numerosity: 15
# 1#1#####1## => True
#     Time Stamp: 9999
#     Average Reward: 0.981689913526
#     Error: 0.0605217279807
#     Fitness: 0.139361925586
#     Experience: 521
#     Action Set Size: 62.89158296168023
#     Numerosity: 18
# 111######01 => True
#     Time Stamp: 9952
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.467014531007
#     Experience: 139
#     Action Set Size: 83.05007994392284
#     Numerosity: 19
# 111#######1 => True
#     Time Stamp: 9952
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.591809762516
#     Experience: 109
#     Action Set Size: 81.14472431542521
#     Numerosity: 21
# 010##0##### => False
#     Time Stamp: 9991
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.725460622944
#     Experience: 187
#     Action Set Size: 54.84000950831609
#     Numerosity: 24
# #11###0###0 => False
#     Time Stamp: 9951
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.737397644127
#     Experience: 155
#     Action Set Size: 83.6464777486848
#     Numerosity: 24
# 1#0####1#1# => True
#     Time Stamp: 9995
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.606710560593
#     Experience: 86
#     Action Set Size: 74.52789424800298
#     Numerosity: 25
# 1#1#1###0#0 => False
#     Time Stamp: 9975
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.742601949045
#     Experience: 85
#     Action Set Size: 75.479913959704
#     Numerosity: 25
# 100####0### => False
#     Time Stamp: 9932
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.903209204725
#     Experience: 106
#     Action Set Size: 59.72663371558246
#     Numerosity: 25
# 0#00#0##### => False
#     Time Stamp: 9966
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.736057428926
#     Experience: 186
#     Action Set Size: 61.638608771113965
#     Numerosity: 28
# 00#11###### => True
#     Time Stamp: 9992
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.78492797199
#     Experience: 535
#     Action Set Size: 84.31258405257977
#     Numerosity: 33
# 0#1#1#1#### => True
#     Time Stamp: 9978
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.813621637225
#     Experience: 325
#     Action Set Size: 75.4028428842268
#     Numerosity: 37
#
# INFO:xcs:Total time: 24.01673 seconds

# %% [markdown]
# ## Usage
#
# Now we'll run through a quick demo of how to use existing algorithms and problems. This is essentially the same code that appears in the test() function we called above.
#
# First, we're going to need to import a few things:

# %%
from xcs import XCSAlgorithm, LCS
from xcs.problems import MUXProblem, OnLineObserver

# %% [markdown]
# The XCSAlgorithm class contains the actual XCS algorithm implementation. The LCS class combines the selected algorithm with its state (a Population instance) to form a learning classifier system. MUXProblem is the classic [multiplexer](http://en.wikipedia.org/wiki/Multiplexer) problem, which defaults to 3 address bits (11 bits total). OnLineObserver is a wrapper for problems which logs the inputs, actions, and rewards as the algorithm attempts to solve the problem.
#
# Now that we've imported the necessary tools, we can define the actual problem, telling it to give the algorithm 10000 reward cycles to attempt to learn the appropriate input/output mapping, and wrapping it with an observer so we can see the algorithm's progress.

# %%
problem = OnLineObserver(MUXProblem(50000))

# %% [markdown]
# Next, we'll create the algorithm which will be used to manage the classifier population and learn the mapping defined by the problem we have selected:

# %%
algorithm = XCSAlgorithm(problem.get_possible_actions())

# %% [markdown]
# We ask the problem for the possible actions that can be taken, and pass them to the XCS algorithm so they can be used in covering operations. (Covering is the generation of a random classifier rule when too few match the current situation.) The algorithm's parameters are set to appropriate defaults for most problems, but it is straight forward to modify them if it becomes necessary.

# %%
algorithm.exploration_probability = .1
algorithm.discount_factor = 0
algorithm.do_GA_subsumption = True
algorithm.do_action_set_subsumption = True

# %% [markdown]
# Here we have selected an exploration probability of .1, which will sacrifice most learning opportunities in favor of taking advantage of what has already been learned so far. This makes sense in real-time learning environment; a lower value is more appropriate in cases where the classifier is being trained in advance or is being used simply to learn a minimal rule set. The discount factor is set to 0, since future rewards are not affected at all by the currently selected action. We have also elected to turn on GA and action set subsumption, which help the system to converge to the minimal effective rule set more quickly in some types of problems.
#
# Next, we create the classifier itself:

# %%
classifier = LCS(algorithm)

# %% [markdown]
# The LCS will create an empty population for us if we do not provide one.
#
# And finally, this is where all the magic happens:

# %%
classifier.learn(problem)

# %% [markdown]
# We pass the problem to the classifier and ask it to learn the appropriate input/output mapping. It executes training cycles until the problem dictates that training should stop. Note that if you wish to see the progress as the algorithm learns the problem, you will need to set the logging level to INFO, as described in the previous section, before calling the learn() method.
#
# Now we can look at the fruits of our labors.

# %%
print(classifier.population)
# Out:
# 00##00####1 => True
#     Time Stamp: 49977
#     Average Reward: 0.87821679153
#     Error: 0.202410212397
#     Fitness: 0.00194208652311
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #001######1 => True
#     Time Stamp: 49979
#     Average Reward: 0.858333333333
#     Error: 0.179444444444
#     Fitness: 0.00747704267322
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #00##1##### => True
#     Time Stamp: 49979
#     Average Reward: 0.635650994586
#     Error: 0.368471665952
#     Fitness: 0.00813172254357
#     Experience: 26
#     Action Set Size: 16.559358046536477
#     Numerosity: 1
# 0#######0## => True
#     Time Stamp: 49952
#     Average Reward: 0.844032029758
#     Error: 0.283404312016
#     Fitness: 0.00863571013407
#     Experience: 22
#     Action Set Size: 14.53429379211057
#     Numerosity: 1
# #0#0###0### => True
#     Time Stamp: 49872
#     Average Reward: 0.670690583534
#     Error: 0.40450684357
#     Fitness: 0.0108553463159
#     Experience: 37
#     Action Set Size: 13.680180299432106
#     Numerosity: 1
# #01####00#0 => True
#     Time Stamp: 49715
#     Average Reward: 0.681143464178
#     Error: 0.38677968066
#     Fitness: 0.0147988696046
#     Experience: 16
#     Action Set Size: 12.247125922570213
#     Numerosity: 1
# ##0######## => False
#     Time Stamp: 49993
#     Average Reward: 0.676754949036
#     Error: 0.423071009609
#     Fitness: 0.0152413219148
#     Experience: 234
#     Action Set Size: 11.232933175668354
#     Numerosity: 1
# 0###0#####1 => True
#     Time Stamp: 49977
#     Average Reward: 0.746484272801
#     Error: 0.284021321457
#     Fitness: 0.0165077362581
#     Experience: 40
#     Action Set Size: 16.14188594814699
#     Numerosity: 1
# ##01#1####0 => True
#     Time Stamp: 49890
#     Average Reward: 0.951889689019
#     Error: 0.131911251966
#     Fitness: 0.0167390564043
#     Experience: 21
#     Action Set Size: 15.571908669508483
#     Numerosity: 1
# #########0# => True
#     Time Stamp: 49965
#     Average Reward: 0.580192763633
#     Error: 0.37999477084
#     Fitness: 0.0169427628253
#     Experience: 60
#     Action Set Size: 11.036799593010455
#     Numerosity: 1
# ##0######00 => False
#     Time Stamp: 49944
#     Average Reward: 0.6239217219
#     Error: 0.397596872394
#     Fitness: 0.0173159854047
#     Experience: 41
#     Action Set Size: 15.39022677591353
#     Numerosity: 1
# ########### => True
#     Time Stamp: 49984
#     Average Reward: 0.554624013524
#     Error: 0.379119719372
#     Fitness: 0.0179877126751
#     Experience: 38
#     Action Set Size: 10.77333887682134
#     Numerosity: 1
# ##0#10###11 => False
#     Time Stamp: 49847
#     Average Reward: 0.889817340287
#     Error: 0.193216417104
#     Fitness: 0.0190183190248
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# #####1###11 => True
#     Time Stamp: 49979
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0213553972477
#     Experience: 1
#     Action Set Size: 18.0
#     Numerosity: 1
# 10#10####0# => False
#     Time Stamp: 49905
#     Average Reward: 0.666666666667
#     Error: 0.222222222222
#     Fitness: 0.0223755417492
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# ####1###0## => False
#     Time Stamp: 49993
#     Average Reward: 0.58952767375
#     Error: 0.426912232134
#     Fitness: 0.024632493104
#     Experience: 42
#     Action Set Size: 13.788834150301245
#     Numerosity: 1
# #1##0##11#0 => True
#     Time Stamp: 49761
#     Average Reward: 0.787895938411
#     Error: 0.298888069774
#     Fitness: 0.0262931541689
#     Experience: 13
#     Action Set Size: 12.181836336458334
#     Numerosity: 1
# 10#00#####1 => True
#     Time Stamp: 49861
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.027742901838
#     Experience: 1
#     Action Set Size: 19.0
#     Numerosity: 1
# 1#0######0# => False
#     Time Stamp: 49993
#     Average Reward: 0.926314020521
#     Error: 0.170743698367
#     Fitness: 0.0281325126257
#     Experience: 16
#     Action Set Size: 14.305128542764031
#     Numerosity: 1
# #0##00###01 => False
#     Time Stamp: 49953
#     Average Reward: 0.79452746487
#     Error: 0.331783728709
#     Fitness: 0.0284848729228
#     Experience: 14
#     Action Set Size: 14.788815802180991
#     Numerosity: 1
# #01#####0## => False
#     Time Stamp: 49971
#     Average Reward: 0.953562249876
#     Error: 0.112893935774
#     Fitness: 0.0303189646113
#     Experience: 21
#     Action Set Size: 15.16628661100138
#     Numerosity: 1
# #01#1##01#0 => True
#     Time Stamp: 49940
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0312056814148
#     Experience: 1
#     Action Set Size: 17.0
#     Numerosity: 1
# 00##01##### => False
#     Time Stamp: 49990
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0320663016671
#     Experience: 1
#     Action Set Size: 11.0
#     Numerosity: 1
# #01##0##### => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0358083472837
#     Experience: 1
#     Action Set Size: 10.0
#     Numerosity: 1
# ####1###### => False
#     Time Stamp: 49993
#     Average Reward: 0.662318336265
#     Error: 0.393197895253
#     Fitness: 0.0359598175182
#     Experience: 64
#     Action Set Size: 13.133603046911192
#     Numerosity: 1
# ##01#1##### => True
#     Time Stamp: 49979
#     Average Reward: 0.822179500131
#     Error: 0.196180685587
#     Fitness: 0.0367880140715
#     Experience: 150
#     Action Set Size: 16.148457969226495
#     Numerosity: 1
# 0#1#0###### => False
#     Time Stamp: 49990
#     Average Reward: 0.97866373643
#     Error: 0.0565410984616
#     Fitness: 0.0391037879631
#     Experience: 22
#     Action Set Size: 13.872924593577531
#     Numerosity: 1
# ##1110#11#1 => True
#     Time Stamp: 49984
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0407310741051
#     Experience: 2
#     Action Set Size: 14.5
#     Numerosity: 1
# 10#00###### => True
#     Time Stamp: 49937
#     Average Reward: 0.908343864711
#     Error: 0.214778662306
#     Fitness: 0.0408728673979
#     Experience: 38
#     Action Set Size: 13.98575364331006
#     Numerosity: 1
# 00##0#####1 => True
#     Time Stamp: 49977
#     Average Reward: 0.609166666667
#     Error: 0.376361111111
#     Fitness: 0.0433981527222
#     Experience: 8
#     Action Set Size: 16.1475
#     Numerosity: 1
# #01#1###110 => True
#     Time Stamp: 49741
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.04664396832
#     Experience: 1
#     Action Set Size: 19.0
#     Numerosity: 1
# #10######0# => False
#     Time Stamp: 49920
#     Average Reward: 0.521214658181
#     Error: 0.425058584834
#     Fitness: 0.0475595373857
#     Experience: 74
#     Action Set Size: 13.99392094950315
#     Numerosity: 1
# ##0##1#10## => True
#     Time Stamp: 49979
#     Average Reward: 0.666666666667
#     Error: 0.222222222222
#     Fitness: 0.0477236964781
#     Experience: 3
#     Action Set Size: 17.333333333333336
#     Numerosity: 1
# #011###1101 => True
#     Time Stamp: 49866
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0480672235119
#     Experience: 3
#     Action Set Size: 19.0
#     Numerosity: 1
# #00###01### => True
#     Time Stamp: 49946
#     Average Reward: 0.729193417728
#     Error: 0.291626062909
#     Fitness: 0.0495381572766
#     Experience: 41
#     Action Set Size: 16.133818103444515
#     Numerosity: 1
# ##01####### => True
#     Time Stamp: 49979
#     Average Reward: 0.6
#     Error: 0.303333333333
#     Fitness: 0.0512458303371
#     Experience: 5
#     Action Set Size: 10.2
#     Numerosity: 1
# #01##0##1## => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0516390326586
#     Experience: 4
#     Action Set Size: 17.5
#     Numerosity: 1
# 111#####0## => False
#     Time Stamp: 49925
#     Average Reward: 0.912998958333
#     Error: 0.149351788194
#     Fitness: 0.0543418868633
#     Experience: 10
#     Action Set Size: 14.330242708333333
#     Numerosity: 1
# #01###111#1 => True
#     Time Stamp: 49540
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.056441849456
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 1#01##10#0# => False
#     Time Stamp: 49993
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.057257468995
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 1##1##001## => True
#     Time Stamp: 49888
#     Average Reward: 0.597863554364
#     Error: 0.39619259636
#     Fitness: 0.0575050505323
#     Experience: 15
#     Action Set Size: 10.128396269967121
#     Numerosity: 1
# ####0###1#0 => True
#     Time Stamp: 49980
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0621131218888
#     Experience: 1
#     Action Set Size: 6.0
#     Numerosity: 1
# ####11###11 => True
#     Time Stamp: 49979
#     Average Reward: 0.879583333333
#     Error: 0.170590277778
#     Fitness: 0.0635548637607
#     Experience: 8
#     Action Set Size: 16.292916666666667
#     Numerosity: 1
# ##11#0#11#1 => True
#     Time Stamp: 49984
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0717198375546
#     Experience: 6
#     Action Set Size: 14.666666666666666
#     Numerosity: 1
# ###00###1#0 => True
#     Time Stamp: 49980
#     Average Reward: 0.75
#     Error: 0.270833333333
#     Fitness: 0.07309729293
#     Experience: 4
#     Action Set Size: 11.5
#     Numerosity: 1
# #0###1##1#0 => True
#     Time Stamp: 49937
#     Average Reward: 0.785498958333
#     Error: 0.250751475694
#     Fitness: 0.078301216905
#     Experience: 10
#     Action Set Size: 13.894096875
#     Numerosity: 1
# 01###0000## => True
#     Time Stamp: 49952
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.0788592656415
#     Experience: 0
#     Action Set Size: 1
#     Numerosity: 1
# 01####0#0## => False
#     Time Stamp: 49959
#     Average Reward: 0.645535225207
#     Error: 0.396548139021
#     Fitness: 0.0809024210894
#     Experience: 123
#     Action Set Size: 14.898853195283179
#     Numerosity: 1
# ####01####1 => True
#     Time Stamp: 49909
#     Average Reward: 0.75
#     Error: 0.1875
#     Fitness: 0.0820242576166
#     Experience: 4
#     Action Set Size: 18.0
#     Numerosity: 1
# #0#1###11#1 => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.0889335992938
#     Experience: 9
#     Action Set Size: 18.60472916666666
#     Numerosity: 1
# #11###0##0# => False
#     Time Stamp: 49925
#     Average Reward: 0.951913436758
#     Error: 0.0913644701602
#     Fitness: 0.0911761271798
#     Experience: 24
#     Action Set Size: 15.63961637840854
#     Numerosity: 1
# 101######## => True
#     Time Stamp: 49937
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.102893479353
#     Experience: 1
#     Action Set Size: 10.0
#     Numerosity: 1
# ###1######0 => True
#     Time Stamp: 49940
#     Average Reward: 0.825069203125
#     Error: 0.211153785938
#     Fitness: 0.105216122909
#     Experience: 13
#     Action Set Size: 12.74202116171875
#     Numerosity: 1
# ####01##### => True
#     Time Stamp: 49980
#     Average Reward: 0.745341009414
#     Error: 0.272042551863
#     Fitness: 0.121131291345
#     Experience: 20
#     Action Set Size: 15.111109870964158
#     Numerosity: 1
# 00####10#1# => True
#     Time Stamp: 49977
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.122919890687
#     Experience: 3
#     Action Set Size: 11.333333333333334
#     Numerosity: 1
# ##0##1###0# => False
#     Time Stamp: 49993
#     Average Reward: 0.440583333333
#     Error: 0.383385416667
#     Fitness: 0.12896037288
#     Experience: 9
#     Action Set Size: 12.618354166666666
#     Numerosity: 1
# ##0##0###11 => False
#     Time Stamp: 49919
#     Average Reward: 0.770393028358
#     Error: 0.267098861358
#     Fitness: 0.143390437143
#     Experience: 35
#     Action Set Size: 14.62540743030331
#     Numerosity: 1
# #01#11#11#1 => True
#     Time Stamp: 49902
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.144468065093
#     Experience: 8
#     Action Set Size: 10.675833333333333
#     Numerosity: 1
# #01#####110 => True
#     Time Stamp: 49741
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.152724153541
#     Experience: 7
#     Action Set Size: 15.883333333333333
#     Numerosity: 1
# ###001##### => True
#     Time Stamp: 49980
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.162113116896
#     Experience: 1
#     Action Set Size: 15.0
#     Numerosity: 1
# 011###0##0# => False
#     Time Stamp: 49908
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.163164590669
#     Experience: 89
#     Action Set Size: 16.74196826289152
#     Numerosity: 1
# #01###100## => True
#     Time Stamp: 49715
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.164819533539
#     Experience: 1
#     Action Set Size: 8.0
#     Numerosity: 1
# 010#1###### => True
#     Time Stamp: 49835
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.166895735219
#     Experience: 1
#     Action Set Size: 10.0
#     Numerosity: 1
# #01#1###1#0 => True
#     Time Stamp: 49940
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.171870084651
#     Experience: 14
#     Action Set Size: 14.966598686796877
#     Numerosity: 1
# #01010##0## => True
#     Time Stamp: 49912
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.180688027333
#     Experience: 5
#     Action Set Size: 12.8
#     Numerosity: 1
# 1#1#####1#0 => False
#     Time Stamp: 49964
#     Average Reward: 0.575
#     Error: 0.349444444444
#     Fitness: 0.200507869309
#     Experience: 7
#     Action Set Size: 10.45
#     Numerosity: 1
# #11###1#### => True
#     Time Stamp: 49984
#     Average Reward: 0.666666666667
#     Error: 0.222222222222
#     Fitness: 0.212491984065
#     Experience: 3
#     Action Set Size: 9.666666666666668
#     Numerosity: 1
# #10#1####11 => True
#     Time Stamp: 49835
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.246278601542
#     Experience: 8
#     Action Set Size: 14.840833333333332
#     Numerosity: 1
# 0#0######0# => False
#     Time Stamp: 49953
#     Average Reward: 0.433333333333
#     Error: 0.347083333333
#     Fitness: 0.246786083157
#     Experience: 7
#     Action Set Size: 13.85
#     Numerosity: 1
# #001####### => True
#     Time Stamp: 49979
#     Average Reward: 0.833333333333
#     Error: 0.138888888889
#     Fitness: 0.269567419489
#     Experience: 6
#     Action Set Size: 13.666666666666666
#     Numerosity: 1
# 0#0#####0## => True
#     Time Stamp: 49890
#     Average Reward: 0.25
#     Error: 0.1875
#     Fitness: 0.329416520852
#     Experience: 4
#     Action Set Size: 15.25
#     Numerosity: 1
# ####11#0#1# => True
#     Time Stamp: 49936
#     Average Reward: 0.893463935293
#     Error: 0.216247582666
#     Fitness: 0.0123569204502
#     Experience: 18
#     Action Set Size: 14.50277341900794
#     Numerosity: 2
# 1#1#####0## => False
#     Time Stamp: 49971
#     Average Reward: 0.986282665587
#     Error: 0.0472899918948
#     Fitness: 0.0139010420376
#     Experience: 56
#     Action Set Size: 15.252309644684654
#     Numerosity: 2
# ##0####1### => True
#     Time Stamp: 49979
#     Average Reward: 0.607844666066
#     Error: 0.396715793453
#     Fitness: 0.0208833018621
#     Experience: 57
#     Action Set Size: 15.053007543780415
#     Numerosity: 2
# #10######1# => True
#     Time Stamp: 49980
#     Average Reward: 0.832591110692
#     Error: 0.254087031891
#     Fitness: 0.0262248143694
#     Experience: 40
#     Action Set Size: 14.273426671949373
#     Numerosity: 2
# #0###1##1## => True
#     Time Stamp: 49937
#     Average Reward: 0.645291666667
#     Error: 0.330502430556
#     Fitness: 0.0635252579517
#     Experience: 9
#     Action Set Size: 14.802020833333334
#     Numerosity: 2
# 0####1##### => True
#     Time Stamp: 49980
#     Average Reward: 0.741299648059
#     Error: 0.309940592127
#     Fitness: 0.0642843737678
#     Experience: 79
#     Action Set Size: 15.834474652057674
#     Numerosity: 2
# 11########0 => False
#     Time Stamp: 49964
#     Average Reward: 0.995969429888
#     Error: 0.0192406217757
#     Fitness: 0.104846799425
#     Experience: 64
#     Action Set Size: 14.494075569258479
#     Numerosity: 2
# #########11 => False
#     Time Stamp: 49981
#     Average Reward: 0.683507723697
#     Error: 0.355627361354
#     Fitness: 0.111734547816
#     Experience: 63
#     Action Set Size: 11.016202761006062
#     Numerosity: 2
# 11########1 => True
#     Time Stamp: 49965
#     Average Reward: 0.83458454957
#     Error: 0.168350943639
#     Fitness: 0.125327310982
#     Experience: 22
#     Action Set Size: 14.120639325593537
#     Numerosity: 2
# 10#10###### => False
#     Time Stamp: 49905
#     Average Reward: 0.8
#     Error: 0.223333333333
#     Fitness: 0.161663291442
#     Experience: 5
#     Action Set Size: 13.4
#     Numerosity: 2
# 1#0####0### => False
#     Time Stamp: 49993
#     Average Reward: 0.90788125
#     Error: 0.119754375
#     Fitness: 0.186012658565
#     Experience: 11
#     Action Set Size: 11.909193385416668
#     Numerosity: 2
# 00##0###### => False
#     Time Stamp: 49990
#     Average Reward: 0.903894445666
#     Error: 0.191816936534
#     Fitness: 0.229814504083
#     Experience: 28
#     Action Set Size: 12.014979230998941
#     Numerosity: 2
# #01#10##1## => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.25482554767
#     Experience: 31
#     Action Set Size: 16.15621837963518
#     Numerosity: 2
# #01#1###1## => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.29924940627
#     Experience: 23
#     Action Set Size: 16.374040246923194
#     Numerosity: 2
# 001#####1#0 => True
#     Time Stamp: 49940
#     Average Reward: 0.912998958333
#     Error: 0.178352135417
#     Fitness: 0.0426071431804
#     Experience: 10
#     Action Set Size: 15.645613541666666
#     Numerosity: 3
# #1########0 => False
#     Time Stamp: 49964
#     Average Reward: 0.750606723743
#     Error: 0.336227277073
#     Fitness: 0.0978542343872
#     Experience: 155
#     Action Set Size: 14.030865504860172
#     Numerosity: 3
# 1##00###### => True
#     Time Stamp: 49942
#     Average Reward: 0.966756018569
#     Error: 0.105832805005
#     Fitness: 0.201620245969
#     Experience: 36
#     Action Set Size: 15.68155957422664
#     Numerosity: 3
# #01#####1#0 => True
#     Time Stamp: 49940
#     Average Reward: 0.998585168223
#     Error: 0.00752996733582
#     Fitness: 0.30869223486
#     Experience: 54
#     Action Set Size: 14.994250322255017
#     Numerosity: 3
# 00101###00# => True
#     Time Stamp: 49912
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.333441822495
#     Experience: 5
#     Action Set Size: 11.6
#     Numerosity: 3
# 1#0####0#0# => False
#     Time Stamp: 49993
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.636688449302
#     Experience: 21
#     Action Set Size: 16.144405825730715
#     Numerosity: 3
# 100####0### => False
#     Time Stamp: 49993
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.678565110288
#     Experience: 1030
#     Action Set Size: 12.883471625034264
#     Numerosity: 3
# 01###00#0## => True
#     Time Stamp: 49952
#     Average Reward: 0.0
#     Error: 0.0
#     Fitness: 0.788592656415
#     Experience: 12
#     Action Set Size: 8.0014738203125
#     Numerosity: 3
# ##0######0# => False
#     Time Stamp: 49993
#     Average Reward: 0.638719618572
#     Error: 0.429316493365
#     Fitness: 0.0586682703204
#     Experience: 94
#     Action Set Size: 13.681254457425062
#     Numerosity: 4
# ##0##0##### => False
#     Time Stamp: 49953
#     Average Reward: 0.737641053316
#     Error: 0.308895954039
#     Fitness: 0.357104738466
#     Experience: 76
#     Action Set Size: 13.457820685022073
#     Numerosity: 4
# #001###1### => True
#     Time Stamp: 49979
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.822238401338
#     Experience: 1664
#     Action Set Size: 19.059402218699194
#     Numerosity: 6
# 111#######0 => False
#     Time Stamp: 49964
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.939363907648
#     Experience: 143
#     Action Set Size: 14.099966000101803
#     Numerosity: 6
# #011###11#1 => True
#     Time Stamp: 49970
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.518716083753
#     Experience: 15
#     Action Set Size: 14.083207478185223
#     Numerosity: 7
# 110######1# => True
#     Time Stamp: 49942
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.882511459016
#     Experience: 2002
#     Action Set Size: 17.21274259731447
#     Numerosity: 7
# 111#######1 => True
#     Time Stamp: 49965
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.894528993288
#     Experience: 1245
#     Action Set Size: 13.28839980317423
#     Numerosity: 7
# 011###1#### => True
#     Time Stamp: 49984
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.902556515139
#     Experience: 323
#     Action Set Size: 15.745776984414219
#     Numerosity: 8
# 011###0#### => False
#     Time Stamp: 49959
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.853021555752
#     Experience: 46
#     Action Set Size: 15.274329978114155
#     Numerosity: 9
# 001#0###### => False
#     Time Stamp: 49990
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.932438846396
#     Experience: 752
#     Action Set Size: 13.743613415253174
#     Numerosity: 9
# 101#####0## => False
#     Time Stamp: 49971
#     Average Reward: 1.0
#     Error: 0.0
#     Fitness: 0.960029964669
#     Experience: 741
#     Action Set Size: 16.74403701264255
#     Numerosity: 10

# %% [markdown]
# This gives us a printout of each rule, in the form *condition => action*, followed by various stats about the rule pertaining to the algorithm we selected. The population can also be accessed as an iterable container:

# %%
print(len(classifier.population))
# Out:
# 104

# %%
for condition, action in classifier.population:
    metadata = classifier.population.get_metadata(condition, action)
    if metadata.fitness > .5:
        print(condition, '=>', action, ' [%.5f]' % metadata.fitness)
# Out:
# 101#####0## => False  [0.96003]
# 001#0###### => False  [0.93244]
# 011###0#### => False  [0.85302]
# 100####0### => False  [0.67857]
# 111#######0 => False  [0.93936]
# 111#######1 => True  [0.89453]
# 110######1# => True  [0.88251]
# #001###1### => True  [0.82224]
# 01###00#0## => True  [0.78859]
# 1#0####0#0# => False  [0.63669]
# 011###1#### => True  [0.90256]
# #011###11#1 => True  [0.51872]
